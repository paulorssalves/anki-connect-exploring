# %%
# VER TODO-LIST em README.md
import re, os
import pandas as pd
import json, time, urllib.request
from tools.tokenization import (get_examples, get_frequency,
                    get_text, get_tokens)
from requests.exceptions import MissingSchema

# %%
from cltk import NLP
from cltk.lemmatize.grc import GreekBackoffLemmatizer
lemmatizer = GreekBackoffLemmatizer()

from cltk.alphabet.text_normalization import cltk_normalize

# %%
from tools.wordstruct import Word as WikWord
from tools.scraper import Word as BibleWord
from tools.scraper import get_link, get_entry_soup, get_word_data, fetch_group_as_string, BASE_URL

# %%
# ways to perfect this function:
# check whether the first word in the concordance example is it
# if not, cut off this word (so as to remove incomplete words)
# do the same to the last word of the sentence
def get_context_example(word, concordance):
    """
    for the purpose of getting an example of the word in question
    being used in context, and cleaning up this example 
    (because NLTK adds a lot of trailing spaces and separates words
    from punctuation signals in the string itself)
    """
    trailing_spaces_start = r"^\s+"
    trailing_spaces_end = r"\s+$"

    context = concordance.concordance_list(word.split()[0])[0][6]
    cleaned_up_pre = re.sub(r'\s([?.!,:;"](?:\s|$))', r'\1', context)
    cleaned_up_start = re.sub(trailing_spaces_start, "", cleaned_up_pre)
    cleaned_up = re.sub(trailing_spaces_end, "", cleaned_up_start)

    return cleaned_up

def clean_up(string):
    trailing_spaces_start = r"^\s+"
    trailing_spaces_end = r"\s+$"

    cleaned_up_pre = re.sub(r'([?.!,:;"](?:\s|$))', "", string.split()[0])
    cleaned_up_start = re.sub(trailing_spaces_start, "", cleaned_up_pre)
    cleaned_up = re.sub(trailing_spaces_end, "", cleaned_up_start)

    return cleaned_up

# %%
songs, wf = get_text("textos/songs.txt")
tokens, token_set, phrases = get_tokens(songs)
frequency = get_frequency(tokens)
cltk_nlp = NLP(language="grc")
cltk_doc = cltk_nlp.analyze(songs)

wordlist = []
for pair in frequency:
    token = pair[0]
    wordlist.append(token)
# Out:
# ‎𐤀 CLTK version '1.0.23'.
# Pipeline for language 'Ancient Greek' (ISO: 'grc'): `GreekNormalizeProcess`, `GreekStanzaProcess`, `GreekEmbeddingsProcess`, `StopsProcess`, `GreekNERProcess`.

# %%
def request(action, **params):
    return {'action': action,
            'params': params,
            'version': 6}

def invoke(action, **params):
    requestJson = json.dumps(request(action, **params)).encode('utf-8')
    response = json.load(urllib.request.urlopen(urllib.request.Request('http://localhost:8765', requestJson)))

    if len(response) != 2:
        raise Exception('response has an unexpected number of fields')

    if 'error' not in response:
        raise Exception('response is missing required error field')
    
    if 'result' not in response:
        raise Exception('response is missing required result field')

    if response['error'] is not None:
        raise Exception(response['error'])

    return response['result']

noteIDs = invoke('findNotes', query='deck:Ελληνικά') 
notesInfo = invoke('notesInfo', notes=noteIDs)

# %%
def get_input_for_material(wordlist, anki_cards):

    notes = []
    for card in anki_cards:
        notes.append(cltk_normalize(clean_up(card['fields']['Word']['value'])))
    fwl = [cltk_normalize(word) for word in wordlist if word not in notes]
    notes_group = lemmatizer.lemmatize(notes)
    fwl_group = lemmatizer.lemmatize(fwl)
    notes_lemmas = set([tuple[1] for tuple in notes_group])
    fwl_lemmas = set([tuple[1] for tuple in fwl_group])

    filtered_fwl_lemmas = [word for word in fwl_lemmas if word not in notes_lemmas]
    reworked_fwl = [tuple for tuple in fwl_group if tuple[1] in filtered_fwl_lemmas]

    for i in range(len(reworked_fwl)):
        if reworked_fwl[i][0] == reworked_fwl[i][1]:
            reworked_fwl[i] = reworked_fwl[i][0]

    return reworked_fwl

reworked_fwl = get_input_for_material(wordlist, notesInfo)

# %%
def fetch_bible_word(word):
    link = get_link(BASE_URL, word)
    soup = get_entry_soup(link)
    word = BibleWord(get_word_data(soup))

    return word

# %%
# isso pode ser aperfeiçoado para tornar mais legível
# em vez de usar uma n-tupla no return value, usar
# um dicionário

def searcher(word):

    if type(word) == tuple:
        try:
            bible_word = fetch_bible_word(word[0])
            return {"search_num": 1, "source": "BibleHub", "input": word[0], "output": bible_word.data}

        except MissingSchema:
            try:
                bible_word = fetch_bible_word(word[1])
                return {"search_num": 2, "source": "BibleHub", "input": word[0], "output": bible_word.data}

            except MissingSchema:

                return {"search_num": 2, "source": None, "input": word[0], "output": None}
                

    elif type(word) == str:
        try: 
            bible_word = fetch_bible_word(word)
            return {"search_num": 1, "source": "BibleHub", "input": word, "output": bible_word.data}

        except:
                return {"search_num": 1, "source": None, "input": word, "output": None}

    else:

        return {"search_num": 0, "source": None, "input": word, "output": None}

# %%
# É necessário criar alguma forma de verificar se
# as palavras que o script adquiriu correspondem às palavras
# do input, uma vez que as palavras obtidas do BibleHub podem ser,
# devido ao meu algoritmo meio porco, não muito confiáveis

# uma ideia interessante seria adicionar um marcador ao lado, algo como 

# Mais uma coisa a aperfeiçoar:
# Se a mesma palavra já estiver presente, deixar de lado
# não o mesmo radical, mas *a mesma palavra*

def acquire_data(list, amount=None):

    bible_searches = 0
    data = []
    blanks = []
    already_present = []

    if (amount != None) and (amount <= len(list)):
        number = range(amount)
    else:
        number = range(len(list))

    for index in number:
        print("word no. {}: {}".format(index+1, list[index]))
        word_dict = searcher(list[index])

        if word_dict["source"] != None:
            result = (word_dict["source"], word_dict["input"], word_dict["output"])
            if result[2] not in already_present:
                data.append(result)
            already_present.append(result[2])
        else:
            blanks.append(word_dict["input"])

        bible_searches += word_dict["search_num"]

        if bible_searches >= 10:
            for n in range(60):
                time.sleep(1)
                print("Wait... {}/60".format(n))
                bible_searches = 0
    
    return data, blanks

data, blanks = acquire_data(reworked_fwl)
# Out:
# word no. 1: ('ἐπέφανεν', 'ἐπιφαίνω')
# word no. 2: εὐλογημένος
# word no. 3: ('ἐπικαλεῖσθε', 'ἐπικαλέω')
# word no. 4: ὄνομα
# word no. 5: ἔλεος
# word no. 6: Πάντα
# word no. 7: ('ἔθνη', 'ἔθνος')
# word no. 8: ἐκύκλωσάν
# word no. 9: ('ἠμυνάμην', 'ἀμύνω')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 10: ('αὐτούς', 'αὐτός')
# word no. 11: Παρὰ
# word no. 12: θαυμαστὴ
# word no. 13: ('ὀφθαλμοῖς', 'ὀφθαλμός')
# word no. 14: Ἐλέησόν
# word no. 15: πλῆθος
# word no. 16: ('ἐξάλειψον', 'ἐξαλείφω')
# word no. 17: ἀνόμημά
# word no. 18: Θεῷ
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 19: Ὑμνοῦμέν
# word no. 20: εὐλογοῦμέν
# word no. 21: προσκυνοῦμέν
# word no. 22: δοξολογοῦμέν
# word no. 23: εὐχαριστοῦμέν
# word no. 24: Βασιλεῦ
# word no. 25: Θεέ
# word no. 26: Πάτερ
# word no. 27: Υἱὲ
# word no. 28: Χριστέ
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 29: Ἅγιον
# word no. 30: Πνεῦμα
# word no. 31: ἀμνὸς
# word no. 32: Υἱός
# word no. 33: Πρόσδεξαι
# word no. 34: ('δέησιν', 'δέω1')
# word no. 35: Καθ
# word no. 36: ('εὐλογήσω', 'εὐλογέω')
# word no. 37: καταφυγὴ
# word no. 38: Ἐγὼ
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 39: εἶπα·
# word no. 40: ἐλέησόν
# word no. 41: ἥμαρτόν
# word no. 42: Παράτεινον
# word no. 43: γινώσκουσί
# word no. 44: Καταξίωσον
# word no. 45: ταύτη
# word no. 46: Πατέρων
# word no. 47: αἰνετὸν
# word no. 48: Γένοιτο
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 49: Δέσποτα
# word no. 50: συνέτισόν
# word no. 51: Ἅγιε
# word no. 52: φώτισόν
# word no. 53: δικαιώμασί
# word no. 54: ('ἔργα', 'ἔργον')
# word no. 55: ('χειρῶν', 'χείρ')
# word no. 56: ('παρίδῃς', 'παρεῖδον')
# word no. 57: αἶνος
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 58: ὕμνος
# word no. 59: Πατρὶ
# word no. 60: Υἱῷ
# word no. 61: Ἁγίῳ
# word no. 62: Πνεύματι
# word no. 63: Ἀγγέλων
# word no. 64: δῆμος
# word no. 65: ('κατεπλάγη', 'καταπλάσσω')
# word no. 66: ('λογισθέντα', 'λογίζομαι')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 67: ('δὲ', 'δέ')
# word no. 68: Σωτήρ
# word no. 69: ('ἰσχὺν', 'ἰσχύς')
# word no. 70: ('καθελόντα', 'καθαιρέω')
# word no. 71: ('ἑαυτῷ', 'ἑαυτοῦ')
# word no. 72: Ἀδὰμ
# word no. 73: ('ἐγείραντα', 'ἐγείρω')
# word no. 74: ᾍδου
# word no. 75: ('ἐλευθερώσαντα', 'ἐλευθερόω')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 76: ('μύρα', 'μύρον')
# word no. 77: ('συμπαθῶς', 'συμπαθής')
# word no. 78: ('δάκρυσιν', 'δάκρυον')
# word no. 79: ὦ
# word no. 80: Μαθήτριαι
# word no. 81: ('κιρνᾶτε', 'κιρνάω')
# word no. 82: ('ἀστράπτων', 'ἀστράπτω')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 83: ('τάφῳ', 'τάφος')
# word no. 84: ('προσεφθέγγετο', 'προσφθέγγομαι')
# word no. 85: Μυροφόροις·
# word no. 86: Ἴδετε
# word no. 87: ('τάφον', 'τάφος')
# word no. 88: ᾔσθητε·
# word no. 89: Σωτὴρ
# word no. 90: ('γὰρ', 'γάρ')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 91: Λίαν
# word no. 92: πρωΐ
# word no. 93: ('ἔδραμον', 'τρέχω')
# word no. 94: θρηνολογοῦσαι·
# word no. 95: ἀλλ
# word no. 96: ('ἐπέστη', 'ἐφίστημι')
# word no. 97: εἶπε·
# word no. 98: ('θρήνου', 'θρῆνος')
# word no. 99: ('καιρὸς', 'καιρός')
# word no. 100: ('πέπαυται', 'παύω')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 101: ('κλαίετε', 'κλαίω')
# word no. 102: Ἀνάστασιν
# word no. 103: δέ
# word no. 104: Ἀποστόλοις
# word no. 105: ('εἴπατε', 'εἶπον')
# word no. 106: ('γυναῖκες', 'γυνή')
# word no. 107: ('μύρων', 'μύρον')
# word no. 108: Σῶτερ
# word no. 109: ('ἐνηχοῦντο', 'ἐνηχέω')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 110: Ἀγγέλου
# word no. 111: ('τρανῶς', 'τρανής')
# word no. 112: φθεγγομένου·
# word no. 113: ζώντα
# word no. 114: ('λογίζεσθε', 'λογίζομαι')
# word no. 115: γάρ
# word no. 116: ('ὀνόματι', 'ὄνομα')
# word no. 117: Ἐξομολογεῖσθε
# word no. 118: Κυρίῳ
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 119: ('αὐτοῦ', 'αὐτός')
# word no. 120: Θεοῦ
# word no. 121: ('αἴρων', 'αἴρω')
# word no. 122: Τὶ
# word no. 123: (';', 'punc')
# word no. 124: Ἄγγελος
# word no. 125: ('ἐξανέστη', 'ἐξανίστημι')
# word no. 126: Μυροφόροι
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 127: μνῆμά
# word no. 128: ('αὐτὰς', 'αὐτός')
# word no. 129: Κυρίου
# word no. 130: Ἀμήν
# word no. 131: Σοὶ
# word no. 132: ('πρέπει', 'πρέπω')
# word no. 133: Θεὸς

# %%
def produce_material(output_file_name, data=None, blanks=None):
    if type(output_file_name) is not str:
        raise TypeError("variable 'output_file_name' must be of type 'str'.")

    if data is not None:
        for item in data:
            if item[0] == "BibleHub":

                print(item[1])

                curr = item[2]
                concordances = curr["concordances"]

                dc = {
                    "word": concordances["Original Word"],
                    "phonetics": concordances["Phonetic Spelling"],
                    "category": concordances["Part of Speech"],
                    "meaning": concordances['Definition'],
                    "greek": fetch_group_as_string([tuple[0] for tuple in curr['examples']], single_list=True),
                    "english": fetch_group_as_string([tuple[1] for tuple in curr['examples']], single_list=True)
                }
                dc["context"] = get_context_example(item[1], wf)
                dc["original"] = item[1]        
                # to display which word is being worked upon at the time

                words_dataframe = pd.DataFrame.from_dict(dc, orient="index")
                words_dataframe = words_dataframe.transpose()
                words_dataframe.to_csv(os.path.join("output", output_file_name+".csv"), 
                                                    encoding="utf-8", mode="a", 
                                                    header=False, index=False)
            
    if blanks is not None:
        blanks_dataframe = pd.DataFrame(blanks)
        blanks_dataframe= blanks_dataframe.transpose()
        blanks_dataframe.to_csv(os.path.join("blanks", output_file_name+"_blanks.csv"), 
                                            encoding="utf-8", mode="a", 
                                            header=False, index=False)

produce_material("test", data=data, blanks=blanks)
# Out:
# ἐπέφανεν
# εὐλογημένος
# ἐπικαλεῖσθε
# ὄνομα
# ἔλεος
# Πάντα
# ἔθνη
# ἠμυνάμην
# αὐτούς
# Παρὰ
# θαυμαστὴ
# ὀφθαλμοῖς
# Ἐλέησόν
# πλῆθος
# ἐξάλειψον
# Θεῷ
# Βασιλεῦ
# Θεέ
# Πάτερ
# Χριστέ
# Ἅγιον
# ἀμνὸς
# Υἱός
# δέησιν
# Καθ
# Ἐγὼ
# Παράτεινον
# γινώσκουσί
# ταύτη
# Γένοιτο
# Δέσποτα
# συνέτισόν
# Ἅγιε
# δικαιώμασί
# ἔργα
# χειρῶν
# αἶνος
# ὕμνος
# Ἀγγέλων
# δῆμος
# λογισθέντα
# δὲ
# Σωτήρ
# ἰσχὺν
# καθελόντα
# ἑαυτῷ
# Ἀδὰμ
# ἐγείραντα
# ᾍδου
# ἐλευθερώσαντα
# μύρα
# συμπαθῶς
# δάκρυσιν
# ὦ
# ἀστράπτων
# τάφῳ
# Ἴδετε
# γὰρ
# Λίαν
# πρωΐ
# ἔδραμον
# ἀλλ
# ἐπέστη
# θρήνου
# καιρὸς
# πέπαυται
# κλαίετε
# Ἀνάστασιν
# Ἀποστόλοις
# εἴπατε
# γυναῖκες
# ζώντα
# Ἐξομολογεῖσθε
# Κυρίῳ
# αἴρων
# Τὶ
# ἐξανέστη
# Κυρίου
# Ἀμήν
# Σοὶ
# πρέπει

# %%
curr_d = data[0][1]
word_name = curr_d['concordances']['Original Word']
concordance = wf.concordance_list(word_name)[0][6]
cleaned_up = re.sub(r'\s([?.!,:;"](?:\s|$))', r'\1', concordance)
pattern = r"^\s+"
cleaned_up = re.sub(pattern,"",cleaned_up)
cleaned_up
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-159-e654d8f28ff3> in <module>()
#       1 curr_d = data[0][1]
# ----> 2 word_name = curr_d['concordances']['Original Word']
#       3 concordance = wf.concordance_list(word_name)[0][6]
#       4 cleaned_up = re.sub(r'\s([?.!,:;"](?:\s|$))', r'\1', concordance)
#       5 pattern = r"^\s+"
#
# TypeError: string indices must be integers

# %%
anesti, wf = get_text("textos/anesti.txt")
tokens, token_set, phrases = get_tokens(anesti)
frequency = get_frequency(tokens)
cltk_nlp = NLP(language="grc")
cltk_doc = cltk_nlp.analyze(anesti)

wordlist = []
for pair in frequency:
    token = pair[0]
    wordlist.append(token)
# Out:
# ‎𐤀 CLTK version '1.0.23'.
# Pipeline for language 'Ancient Greek' (ISO: 'grc'): `GreekNormalizeProcess`, `GreekStanzaProcess`, `GreekEmbeddingsProcess`, `StopsProcess`, `GreekNERProcess`.

# %%
type(os.path.join("textos", "songs.csv"))
# Out:
# str

# %%
# Out:
# 133

# %%
len(noteIDs)
# Out:
# 224

# %%
fwl_lemmas
# Out:
# {'punc',
#  'Χριστὸς',
#  'ζωή',
#  'θάνατος',
#  'μνῆμα',
#  'νεκρός',
#  'πατέω',
#  'χαρίζομαι',
#  'ἀνίστημι',
#  'ἐκ'}

# %%
notes_lemmas
# Out:
# {'Δόξα',
#  'Εὐλογητὸς',
#  'Θεός',
#  'Θεὸν',
#  'Κύριε',
#  'Μαρία',
#  'Πατρός',
#  'Πιλᾶτος',
#  'Προσδοκῶ',
#  'Πόντιος',
#  'Σταυρωθέντα',
#  'Χριστός',
#  'αἰνέω',
#  'αἰών',
#  'αἴνεσις',
#  'βάπτισμα',
#  'βασίλειος',
#  'γίγνομαι',
#  'γενεά',
#  'γεννάω',
#  'γιγνώσκω',
#  'γραφή',
#  'γῆ',
#  'δέησις',
#  'δίδαξόν',
#  'δίδωμι',
#  'δείκνυμι',
#  'δεξιός',
#  'διά',
#  'δικαιώματά',
#  'δι’',
#  'δοξάζω',
#  'δόξα',
#  'δύναμις',
#  'εἰμί',
#  'εἰρήνη',
#  'εἰς',
#  'εἰσφέρω',
#  'εἶμι',
#  'εἷς',
#  'εὐδοκία',
#  'εὐλογέω',
#  'εὐλογία',
#  'εὐχαριστέω',
#  'ζάω',
#  'ζωή',
#  'ζωοποιός',
#  'θάπτω',
#  'θέλημά',
#  'θεός',
#  'κάθημαι',
#  'καί',
#  'καθά',
#  'καθολικὴν',
#  'κατά',
#  'κατάνυξις',
#  'κατάἕζομαι',
#  'κατέρχομαι',
#  'καταφεύγω',
#  'κρίνω',
#  'κόσμος',
#  'κύριος',
#  'λέγω',
#  'λαλέω',
#  'μέγας',
#  'μέλλω',
#  'μή',
#  'μήτηρ',
#  'μακαρίζω',
#  'μεγαλύνω',
#  'μετά',
#  'μονογενής',
#  'μόνος',
#  'νεκρός',
#  'νῦν',
#  'οὐ',
#  'οὐρανός',
#  'οὗτος',
#  'πάλιν',
#  'πάσχω',
#  'παναμώμητον',
#  'παντοκράτωρ',
#  'παρά',
#  'παρατείνω',
#  'παρθένος',
#  'πατήρ',
#  'πειρασμός',
#  'πηγή',
#  'πιστεύω',
#  'πνεῦμα',
#  'ποιέω',
#  'ποιητής',
#  'πονηρός',
#  'προσεύχομαι',
#  'προσκυνέω',
#  'προφήτης',
#  'πρό',
#  'πρός',
#  'πᾶς',
#  'σήμερον',
#  'σαρκόω',
#  'συνδοξάζω',
#  'σωτήρ',
#  'σωτηρία',
#  'σύ',
#  'σύν',
#  'τέλος',
#  'τίκτω',
#  'τίμιος',
#  'τε',
#  'τρίτος',
#  'υἱός',
#  'φάος',
#  'φυλάσσω',
#  'φώς',
#  'ψυχή',
#  'ἀδιάφθορος',
#  'ἀεί',
#  'ἀειμακάριστον',
#  'ἀθάνατος',
#  'ἀληθής',
#  'ἀληθινός',
#  'ἀλλά',
#  'ἀμνός',
#  'ἀνάστασις',
#  'ἀνέρχομαι',
#  'ἀνίστημι',
#  'ἀναμάρτητος',
#  'ἀποστολικὴν',
#  'ἀπό',
#  'ἀσύγκριτος',
#  'ἀφίημι',
#  'ἀόρατος',
#  'ἁγιάζω',
#  'ἁμαρτάνω',
#  'ἁμαρτία',
#  'ἁμός',
#  'ἄνθρωπος',
#  'ἄρτος',
#  'ἄφεσις',
#  'ἅγιος',
#  'Ἀγρίππας',
#  'Ἅγιος',
#  'ἐγώ',
#  'ἐκ',
#  'ἐκκλησία',
#  'ἐκπορεύω',
#  'ἐλεέω',
#  'ἐλπίζω',
#  'ἐν',
#  'ἐνανθρωπέω',
#  'ἐπί',
#  'ἐπιούσιος',
#  'ἐπουράνιος',
#  'ἔλεός',
#  'ἔνδοξος',
#  'ἔρχομαι',
#  'ἕκαστος',
#  'ἡμέρα',
#  'ἡμέτερος',
#  'ἰάομαι',
#  'ἵημι',
#  'Ἰησοῦ',
#  'Ἰησοῦς',
#  'Ἰσχυρός',
#  'ὀφείλημα',
#  'ὀφειλέτης',
#  'ὁ',
#  'ὁμολογέω',
#  'ὁμοούσιος',
#  'ὁράω',
#  'ὁρατός',
#  'ὄνομά',
#  'ὄντως',
#  'ὅτι',
#  'ὑπέρ',
#  'ὕψιστος',
#  'ὡς',
#  'ῥύομαι'}

# %%
clean_up(notes[188])
# Out:
# 'νεκρός'

# %%
notes
# Out:
# ['καὶ',
#  'Ἅγιος',
#  'ὁ',
#  'Κύριε',
#  'ἡμᾶς',
#  'σου',
#  'τοῦ',
#  'ἐν',
#  'τὸ',
#  'εἰς',
#  'εἶ',
#  'ἐλέησον',
#  'Θεός',
#  'σε',
#  'ἀθάνατος',
#  'με',
#  'ἡμῶν',
#  'ἡ',
#  'Ἰσχυρός',
#  'τὰ',
#  'δίδαξόν',
#  'Εὐλογητὸς',
#  'τὸν',
#  'τὴν',
#  'τοῖς',
#  'ἡμῖν',
#  'δικαιώματά',
#  'τοὺς',
#  'ὄνομά',
#  'σὺ',
#  'δὸς',
#  'τῆς',
#  'νῦν',
#  'φωτί',
#  'σοὶ',
#  'παρὰ',
#  'ποιεῖν',
#  'σὲ',
#  'πρὸς',
#  'ψυχήν',
#  'σέ',
#  'ἠλπίσαμεν',
#  'καθάπερ',
#  'ταύτῃ',
#  'ἡμέρᾳ',
#  'τῇ',
#  'αἰῶνος',
#  'ἡμέραν',
#  'ἑκάστην',
#  'Ἰησοῦς',
#  'δεξιᾷ',
#  'τὰς',
#  'Ἰησοῦ',
#  'μεγάλην',
#  'διὰ',
#  'ἀνθρώποις',
#  'εἰρήνη',
#  'γῆς',
#  'ὑψίστοις',
#  'Ὅτι',
#  'Πατρός',
#  'ἐπὶ',
#  'Δόξα',
#  'ὡς',
#  'βασιλεία',
#  'θέλημά',
#  'ὅτι',
#  'μου',
#  'ἔλεός',
#  'τῶν',
#  'μόνος',
#  'κόσμου',
#  'δόξαν',
#  'σοι',
#  'φῶς',
#  'τῷ',
#  'ἀμήν',
#  'δόξα',
#  'δύναμις',
#  'ἐστιν',
#  'σοῦ',
#  'ἀπὸ',
#  'ἀλλὰ',
#  'ἡμεῖς',
#  'γενεᾷ',
#  'πονηροῦ',
#  'ῥῦσαι',
#  'πειρασμόν',
#  'εἰσενέγκῃς',
#  'μὴ',
#  'σωτήρ',
#  'ὀφειλέτης',
#  'ἀφίημι',
#  'ὀφείλημα',
#  'σήμερον',
#  'εὐχαριστέω',
#  'δοξάζω',
#  'προσκυνέω',
#  'εὐλογία',
#  'εὐδοκία',
#  'σύ',
#  'δείκνυμι',
#  'μονογενής',
#  'ἐλεέω',
#  'παντοκράτωρ',
#  'θεός',
#  'ἐπουράνιος',
#  'Ἀγρίππας',
#  'ἁμαρτία',
#  'υἱός',
#  'ἀμνός',
#  'πνεῦμα',
#  'Χριστός',
#  'κάθημαι',
#  'δέησις',
#  'προσεύχομαι',
#  'αἴνεσις',
#  'εὐλογέω',
#  'κατά',
#  'κύριος',
#  'κατάνυξις',
#  'φυλάσσω',
#  'ἀναμάρτητος',
#  'ἐπί',
#  'γίνομαι',
#  'αἰνέω',
#  'πατήρ',
#  'ἰάομαι',
#  'λέγω',
#  'ἐγώ',
#  'ἁμαρτάνω',
#  'καταφεύγω',
#  'ζωή',
#  'πηγή',
#  'γινώσκω',
#  'παρατείνω',
#  'ὁράω',
#  'αἰών',
#  'ἀεί',
#  'ἔρχομαι',
#  'ἁγιάζω',
#  'οὐρανός',
#  'ἐπιούσιος',
#  'ἄρτος',
#  'ἀληθῶς',
#  'μακαρίζειν',
#  'ἀειμακάριστον',
#  'παναμώμητον',
#  'μητέρα',
#  'τιμιωτέραν',
#  'ἀσυγκρίτως',
#  'ἐνδοξοτέραν',
#  'ἀδιαφθόρως',
#  'Θεὸν',
#  'τεκοῦσαν',
#  'ὄντως',
#  'μεγαλύνομεν',
#  'ἅγιος',
#  'δι’',
#  'ἀληθινός',
#  'ἀμήν',
#  'ἀνάστασις',
#  'ἀνέρχομαι',
#  'ἀνίστημι',
#  'ἀόρατος',
#  'ἄφεσις',
#  'βάπτισμα',
#  'βασιλεία',
#  'γεννάω',
#  'γραφή',
#  'εἰς',
#  'εἷς',
#  'ἐκ',
#  'ἐκκλησία',
#  'ἐκπορεύομαι',
#  'ζάω',
#  'ἡμέτερος',
#  'θάπτω',
#  'θεός',
#  'Ἰησοῦς',
#  'καθέζομαι',
#  'κατέρχομαι',
#  'κρίνω',
#  'κύριος',
#  'λαλέω',
#  'Μαρία',
#  'μέλλω',
#  'μετά',
#  'νεκρός',
#  'ὁμολογέω',
#  'ὁμοούσιος',
#  'ὁρατός',
#  'οὐ',
#  'οὗ',
#  'οὐρανός',
#  'πάλιν',
#  'παρθένος',
#  'πᾶς',
#  'πάσχω',
#  'πατήρ',
#  'Πιλᾶτος',
#  'πιστεύω',
#  'πνεῦμα',
#  'ποιητής',
#  'Πόντιος',
#  'πρό',
#  'προφήτης',
#  'σύν',
#  'συνδοξάζω',
#  'σωτηρία',
#  'τέ',
#  'τέλος',
#  'τρίτος',
#  'υἱός',
#  'ὑπέρ',
#  'φῶς',
#  'Χριστός',
#  'ἐνανθρωπήσαντα',
#  'Σταυρωθέντα',
#  'ζωοποιόν',
#  'καθολικὴν',
#  'ἀποστολικὴν',
#  'Προσδοκῶ',
#  'σαρκωθέντα']

# %%
d = [(1,2,3), 4, 5, (6,7,8)]

# %%
# Out:
# True
