# %%
# VER TODO-LIST em README.md
import re, os, string
import pandas as pd
import json, time, urllib.request
from tools.tokenization import (get_examples, get_frequency,
                    get_text, get_tokens)
from requests.exceptions import MissingSchema

# %%
from cltk import NLP
from cltk.lemmatize.grc import GreekBackoffLemmatizer
lemmatizer = GreekBackoffLemmatizer()

from cltk.alphabet.text_normalization import cltk_normalize

# %%
from tools.wordstruct import Word as WikWord
from tools.scraper import Word as BibleWord
from tools.scraper import get_link, get_entry_soup, get_word_data, fetch_group_as_string, BASE_URL

# %%
# ways to perfect this function:
# check whether the first word in the concordance example is it
# if not, cut off this word (so as to remove incomplete words)
# do the same to the last word of the sentence

def boldify_selected_word(word, string):
    string_l = string.split()
    for index in range(len(string_l)):
        if string_l[index] == word:
            bold = "<b>"+word+"</b>"
            string_l[index] = bold 
    return string_l, bold

def get_context_and_clean_up(word, concordance):

    # get word context from concordance
    c = concordance.concordance_list(cltk_normalize(word))

    # split string and make chosen word bold
    line, bold_word = boldify_selected_word(cltk_normalize(word), c[0][6])
    word_list = line

    # remove first and last words of string, as they are sometimes incomplete
    # and assert that the first and last 
    if word_list[0] not in (word, bold_word):
        del word_list[0]
        if word_list[0] in string.punctuation:
            del word_list[0] 
    if word_list[len(word_list) - 1] not in (word, bold_word):
        del word_list[len(word_list) - 1]

    # get string with extra spaces
    unfinished_string = " ".join(word_list)
    
    # remove unnecessary spaces from string
    trailing_spaces_start = r"^\s+"
    trailing_spaces_end = r"\s+$"

    cleaned_up_pre = re.sub(r'\s([?.!,:;"](?:\s|$))', r'\1', unfinished_string)
    cleaned_up_start = re.sub(trailing_spaces_start, "", cleaned_up_pre)
    final_string = re.sub(trailing_spaces_end, "", cleaned_up_start)
    
    return final_string

def clean_up(string):
    trailing_spaces_start = r"^\s+"
    trailing_spaces_end = r"\s+$"

    cleaned_up_pre = re.sub(r'([?.!,:;"](?:\s|$))', "", string.split()[0])
    cleaned_up_start = re.sub(trailing_spaces_start, "", cleaned_up_pre)
    cleaned_up = re.sub(trailing_spaces_end, "", cleaned_up_start)

    return cleaned_up

# %%
import csv

wordlist = []
f = open("gathering.csv", encoding="UTF8")
csv_reader = csv.reader(f)
for line in csv_reader:
    wordlist.append(line[0])

print(wordlist)
# Out:
# ['παιδοφθορήσεις', 'μνησικακήσεις', 'διγνώμων', 'πονηρὰν', 'ῷος', 'παιδοφθορήσεις', 'διαφορὰ', 'διαφορὰ', 'ἀνέπεμψα', 'προσλαβοῦ', 'εὐαγγελίου', 'ἀπέχῃς', 'ἠδίκησ', 'ἐλλόγει', 'ἀποτίσω', 'ἠδίκησέ', 'εὔφρανον', 'ἐπωνύμῳ', 'νῶτον', 'ᾐτήσατό', 'ἐλλόγει', 'ὁλοκαύτωμά', 'ὑπερασπίσαι', 'ἠδίκησέ', 'Ἐπακούσαι', 'ἀποτίσω', '', 'ἐκύκλωσάν', 'διαφορὰ', 'αἰτήματά', 'ἐπικαλεσώμεθά', 'εὐφρανεῖς', 'ἀντιλάβοιτό', 'γίνεσθαί', 'μισοῦντάς', 'φώτισόν', 'παρίδῃς', 'κατεπλάγη', 'Μαθήτριαι', 'αἰνετὸν', 'Καταξίωσον', 'ἥμαρτόν', 'εἶπα', 'καταφυγὴ', 'Πρόσδεξαι', 'ἀνόμημά', 'ἀήττητον', 'τρόπαιον', 'Προστασία', 'ἀκαταίσχυντε', 'παρίδῃς', 'ἱκεσίας', 'πανύμνητε', 'ἐνηχοῦντο', 'τρανῶς', 'φθεγγομένου', 'θρηνολογοῦσαι', 'ᾔσθητε', 'Μυροφόροις', 'κιρνᾶτε', 'προσεφθέγγετο', 'Ἱδρωσάτω']

# %%
def request(action, **params):
    return {'action': action,
            'params': params,
            'version': 6}

def invoke(action, **params):
    requestJson = json.dumps(request(action, **params)).encode('utf-8')
    response = json.load(urllib.request.urlopen(urllib.request.Request('http://localhost:8765', requestJson)))

    if len(response) != 2:
        raise Exception('response has an unexpected number of fields')

    if 'error' not in response:
        raise Exception('response is missing required error field')
    
    if 'result' not in response:
        raise Exception('response is missing required result field')

    if response['error'] is not None:
        raise Exception(response['error'])

    return response['result']

noteIDs = invoke('findNotes', query='deck:Grego') 
notesInfo = invoke('notesInfo', notes=noteIDs)

# %%
def get_input_for_material(wordlist, anki_cards):

    notes = []
    for card in anki_cards:
        notes.append(cltk_normalize(clean_up(card['fields']['Word']['value'])))
    fwl = [cltk_normalize(word) for word in wordlist if word not in notes]
    notes_group = lemmatizer.lemmatize(notes)
    fwl_group = lemmatizer.lemmatize(fwl)
    notes_lemmas = set([tuple[1] for tuple in notes_group])
    fwl_lemmas = set([tuple[1] for tuple in fwl_group])

    filtered_fwl_lemmas = [word for word in fwl_lemmas if word not in notes_lemmas]
    reworked_fwl = [tuple for tuple in fwl_group if tuple[1] in filtered_fwl_lemmas]

    for i in range(len(reworked_fwl)):
        if reworked_fwl[i][0] == reworked_fwl[i][1]:
            reworked_fwl[i] = reworked_fwl[i][0]

    return reworked_fwl

reworked_fwl = get_input_for_material(wordlist, notesInfo)

# %%
reworked_fwl
# Out:
# ['παιδοφθορήσεις',
#  ('μνησικακήσεις', 'μνησικακέω'),
#  ('διγνώμων', 'δίγνωμος'),
#  'πονηρὰν',
#  'ῷος',
#  'παιδοφθορήσεις',
#  ('διαφορὰ', 'διαφορά'),
#  ('διαφορὰ', 'διαφορά'),
#  ('ἀνέπεμψα', 'ἀναπέμπω'),
#  ('εὐαγγελίου', 'εὐαγγέλιος'),
#  ('ἀπέχῃς', 'ἀπέχω'),
#  'ἠδίκησ',
#  ('ἐλλόγει', 'ἐλλογάω'),
#  ('ἀποτίσω', 'ἀποτίνω'),
#  'ἠδίκησέ',
#  ('εὔφρανον', 'εὐφραίνω'),
#  ('ἐπωνύμῳ', 'ἐπώνυμος'),
#  'νῶτον',
#  'ᾐτήσατό',
#  ('ἐλλόγει', 'ἐλλογάω'),
#  'ὁλοκαύτωμά',
#  ('ὑπερασπίσαι', 'ὑπερασπίζω'),
#  'ἠδίκησέ',
#  'Ἐπακούσαι',
#  ('ἀποτίσω', 'ἀποτίνω'),
#  '',
#  'ἐκύκλωσάν',
#  ('διαφορὰ', 'διαφορά'),
#  'αἰτήματά',
#  'ἐπικαλεσώμεθά',
#  ('εὐφρανεῖς', 'εὐφραίνω'),
#  'ἀντιλάβοιτό',
#  'γίνεσθαί',
#  'μισοῦντάς',
#  'φώτισόν',
#  ('παρίδῃς', 'παρεῖδον'),
#  ('κατεπλάγη', 'καταπλάσσω'),
#  'Μαθήτριαι',
#  'αἰνετὸν',
#  'Καταξίωσον',
#  'ἥμαρτόν',
#  ('εἶπα', 'εἶπον'),
#  'καταφυγὴ',
#  'Πρόσδεξαι',
#  'ἀνόμημά',
#  ('ἀήττητον', 'ἀήσσητος'),
#  'τρόπαιον',
#  'Προστασία',
#  'ἀκαταίσχυντε',
#  ('παρίδῃς', 'παρεῖδον'),
#  ('ἱκεσίας', 'ἱκέσιος'),
#  'πανύμνητε',
#  ('ἐνηχοῦντο', 'ἐνηχέω'),
#  ('τρανῶς', 'τρανής'),
#  ('φθεγγομένου', 'φθέγγομαι'),
#  'θρηνολογοῦσαι',
#  'ᾔσθητε',
#  'Μυροφόροις',
#  ('κιρνᾶτε', 'κιρνάω'),
#  ('προσεφθέγγετο', 'προσφθέγγομαι'),
#  'Ἱδρωσάτω']

# %%
def fetch_bible_word(word):
    link = get_link(BASE_URL, word)
    soup = get_entry_soup(link)
    word = BibleWord(get_word_data(soup))

    return word

# %%
def searcher(word):

    if type(word) == tuple:
        try:
            bible_word = fetch_bible_word(word[0])
            return {"search_num": 1, "source": "BibleHub", "input": word[0], "output": bible_word.data}

        except MissingSchema:
            try:
                bible_word = fetch_bible_word(word[1])
                return {"search_num": 2, "source": "BibleHub", "input": word[0], "output": bible_word.data}

            except MissingSchema:

                return {"search_num": 2, "source": None, "input": word[0], "output": None}
                

    elif type(word) == str:
        try: 
            bible_word = fetch_bible_word(word)
            return {"search_num": 1, "source": "BibleHub", "input": word, "output": bible_word.data}

        except:
                return {"search_num": 1, "source": None, "input": word, "output": None}

    else:

        return {"search_num": 0, "source": None, "input": word, "output": None}

# %%
# É necessário criar alguma forma de verificar se
# as palavras que o script adquiriu correspondem às palavras
# do input, uma vez que as palavras obtidas do BibleHub podem ser,
# devido ao meu algoritmo meio porco, não muito confiáveis

# uma ideia interessante seria adicionar um marcador ao lado, algo como 

# Mais uma coisa a aperfeiçoar:
# Se a mesma palavra já estiver presente, deixar de lado
# não o mesmo radical, mas *a mesma palavra*

def acquire_data(list, amount=None):

    bible_searches = 0
    data = []
    blanks = []
    already_present = []

    if (amount != None) and (amount <= len(list)):
        number = range(amount)
    else:
        number = range(len(list))

    for index in number:
        print("word no. {}: {}".format(index+1, list[index]))
        word_dict = searcher(list[index])

        if word_dict["source"] != None:
            result = (word_dict["source"], word_dict["input"], word_dict["output"])
            if result[2] not in already_present:
                data.append(result)
            already_present.append(result[2])
        else:
            blanks.append(word_dict["input"])

        bible_searches += word_dict["search_num"]

        if bible_searches >= 10:
            for n in range(60):
                time.sleep(1)
                print("Wait... {}/60".format(n))
                bible_searches = 0
    
    return data, blanks

data, blanks = acquire_data(reworked_fwl)
# Out:
# word no. 1: παιδοφθορήσεις
# word no. 2: ('μνησικακήσεις', 'μνησικακέω')
# word no. 3: ('διγνώμων', 'δίγνωμος')
# word no. 4: πονηρὰν
# word no. 5: ῷος
# word no. 6: παιδοφθορήσεις
# word no. 7: ('διαφορὰ', 'διαφορά')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 8: ('διαφορὰ', 'διαφορά')
# word no. 9: ('ἀνέπεμψα', 'ἀναπέμπω')
# word no. 10: ('εὐαγγελίου', 'εὐαγγέλιος')
# word no. 11: ('ἀπέχῃς', 'ἀπέχω')
# word no. 12: ἠδίκησ
# word no. 13: ('ἐλλόγει', 'ἐλλογάω')
# word no. 14: ('ἀποτίσω', 'ἀποτίνω')
# word no. 15: ἠδίκησέ
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 16: ('εὔφρανον', 'εὐφραίνω')
# word no. 17: ('ἐπωνύμῳ', 'ἐπώνυμος')
# word no. 18: νῶτον
# word no. 19: ᾐτήσατό
# word no. 20: ('ἐλλόγει', 'ἐλλογάω')
# word no. 21: ὁλοκαύτωμά
# word no. 22: ('ὑπερασπίσαι', 'ὑπερασπίζω')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 23: ἠδίκησέ
# word no. 24: Ἐπακούσαι
# word no. 25: ('ἀποτίσω', 'ἀποτίνω')
# word no. 26:
# word no. 27: ἐκύκλωσάν
# word no. 28: ('διαφορὰ', 'διαφορά')
# word no. 29: αἰτήματά
# word no. 30: ἐπικαλεσώμεθά
# word no. 31: ('εὐφρανεῖς', 'εὐφραίνω')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 32: ἀντιλάβοιτό
# word no. 33: γίνεσθαί
# word no. 34: μισοῦντάς
# word no. 35: φώτισόν
# word no. 36: ('παρίδῃς', 'παρεῖδον')
# word no. 37: ('κατεπλάγη', 'καταπλάσσω')
# word no. 38: Μαθήτριαι
# word no. 39: αἰνετὸν
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 40: Καταξίωσον
# word no. 41: ἥμαρτόν
# word no. 42: ('εἶπα', 'εἶπον')
# word no. 43: καταφυγὴ
# word no. 44: Πρόσδεξαι
# word no. 45: ἀνόμημά
# word no. 46: ('ἀήττητον', 'ἀήσσητος')
# word no. 47: τρόπαιον
# word no. 48: Προστασία
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 49: ἀκαταίσχυντε
# word no. 50: ('παρίδῃς', 'παρεῖδον')
# word no. 51: ('ἱκεσίας', 'ἱκέσιος')
# word no. 52: πανύμνητε
# word no. 53: ('ἐνηχοῦντο', 'ἐνηχέω')
# word no. 54: ('τρανῶς', 'τρανής')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 55: ('φθεγγομένου', 'φθέγγομαι')
# word no. 56: θρηνολογοῦσαι
# word no. 57: ᾔσθητε
# word no. 58: Μυροφόροις
# word no. 59: ('κιρνᾶτε', 'κιρνάω')
# word no. 60: ('προσεφθέγγετο', 'προσφθέγγομαι')
# word no. 61: Ἱδρωσάτω
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60

# %%
data, blanks
# Out:
# ([('BibleHub',
#    'ἀνέπεμψα',
#    {'concordances': {'Original Word': 'ἀναπέμπω',
#      'Part of Speech': 'Verb',
#      'Transliteration': 'anapempó',
#      'Phonetic Spelling': "(an-ap-em'-po)",
#      'Definition': 'to send up',
#      'Usage': 'I send up (to a higher tribunal), send back.'},
#     'examples': [('ἐσθῆτα λαμπρὰν ἀνέπεμψεν αὐτὸν τῷ',
#       ' apparel splendid he sent back him to'),
#      ('οὐδὲ Ἡρῴδης ἀνέπεμψεν γὰρ αὐτὸν',
#       ' not even Herod he sent back indeed him'),
#      ('ἕως οὗ ἀναπέμψω αὐτὸν πρὸς', ' until that I might send him to')]}),
#   ('BibleHub',
#    'εὐαγγελίου',
#    {'concordances': {'Original Word': 'εὐαγγέλιον, ου, τό',
#      'Part of Speech': 'Noun, Neuter',
#      'Transliteration': 'euaggelion',
#      'Phonetic Spelling': "(yoo-ang-ghel'-ee-on)",
#      'Definition': 'good news',
#      'Usage': 'the good news of the coming of the Messiah, the gospel; the gen. after it expresses sometimes the giver (God), sometimes the subject (the Messiah, etc.), sometimes the human transmitter (an apostle).'},
#     'examples': [('κηρύσσων τὸ εὐαγγέλιον τῆς βασιλείας',
#       ' proclaiming the gospel of the kingdom'),
#      ('τοῦτο τὸ εὐαγγέλιον τῆς βασιλείας', ' this gospel of the kingdom'),
#      ('κηρυχθῇ τὸ εὐαγγέλιον τοῦτο ἐν',
#       ' shall be proclaimed the gospel this in')]}),
#   ('BibleHub',
#    'ἀπέχῃς',
#    {'concordances': {'Original Word': 'ἀπέχω',
#      'Part of Speech': 'Verb',
#      'Transliteration': 'apechó',
#      'Phonetic Spelling': "(ap-ekh'-o)",
#      'Definition': 'to hold back, keep off, to be away, be distant',
#      'Usage': 'I have in full, am far, it is enough.'},
#     'examples': [('λέγω ὑμῖν ἀπέχουσιν τὸν μισθὸν',
#       ' I say to you they have the reward'),
#      ('λέγω ὑμῖν ἀπέχουσιν τὸν μισθὸν', ' I say to you they have the reward'),
#      ('τῆς γῆς ἀπεῖχεν βασανιζόμενον ὑπὸ', ' the land being tossed by')]}),
#   ('BibleHub',
#    'ἐλλόγει',
#    {'concordances': {'Original Word': 'ἐλλογέω',
#      'Part of Speech': 'Verb',
#      'Transliteration': 'ellogeó',
#      'Phonetic Spelling': "(el-log-eh'-o)",
#      'Definition': "to charge to one's account, impute",
#      'Usage': "I charge to, put to one's account, impute."},
#     'examples': [('τοῦτο ἐμοὶ ἐλλόγα ',
#       ' this to me charge to the account')]}),
#   ('BibleHub',
#    'ἀποτίσω',
#    {'concordances': {'Original Word': 'ἀποτίνω',
#      'Part of Speech': 'Verb',
#      'Transliteration': 'apotinó',
#      'Phonetic Spelling': "(ap-ot-ee'-no)",
#      'Definition': 'to pay off, repay',
#      'Usage': 'I repay, pay what is due (by way of punishment or fine), make good.'},
#     'examples': []}),
#   ('BibleHub',
#    'νῶτον',
#    {'concordances': {'Original Word': 'νῶτος, ου, ὁ',
#      'Part of Speech': 'Noun, Masculine',
#      'Transliteration': 'nótos',
#      'Phonetic Spelling': "(no'-tos)",
#      'Definition': 'the back',
#      'Usage': 'the back (of men or animals).'},
#     'examples': []}),
#   ('BibleHub',
#    'εἶπα',
#    {'concordances': {'Original Word': 'λέγω',
#      'Part of Speech': 'Verb',
#      'Transliteration': 'legó',
#      'Phonetic Spelling': "(leg'-o)",
#      'Definition': 'to say',
#      'Usage': '(denoting speech in progress), (a) I say, speak; I mean, mention, tell, (b) I call, name, especially in the pass., (c) I tell, command.'},
#     'examples': [('ἐφάνη αὐτῷ λέγων Ἰωσὴφ υἱὸς',
#       ' appeared to him saying Joseph son'),
#      ('τοῦ προφήτου λέγοντος ', ' the prophet saying'),
#      ('λέγοντες Ποῦ ἐστὶν', ' saying Where is')]}),
#   ('BibleHub',
#    'φθεγγομένου',
#    {'concordances': {'Original Word': 'φθέγγομαι',
#      'Part of Speech': 'Verb',
#      'Transliteration': 'phtheggomai',
#      'Phonetic Spelling': "(ftheng'-gom-ahee)",
#      'Definition': 'to utter',
#      'Usage': 'I speak aloud, utter.'},
#     'examples': [('ἀνθρώπου φωνῇ φθεγξάμενον ἐκώλυσεν τὴν',
#       " a man's voice having spoken forbade the"),
#      ('γὰρ ματαιότητος φθεγγόμενοι δελεάζουσιν ἐν',
#       ' indeed of vanity speaking they allure with')]})],
#  ['παιδοφθορήσεις',
#   'μνησικακήσεις',
#   'διγνώμων',
#   'πονηρὰν',
#   'ῷος',
#   'παιδοφθορήσεις',
#   'διαφορὰ',
#   'διαφορὰ',
#   'ἠδίκησ',
#   'ἠδίκησέ',
#   'εὔφρανον',
#   'ἐπωνύμῳ',
#   'ᾐτήσατό',
#   'ὁλοκαύτωμά',
#   'ὑπερασπίσαι',
#   'ἠδίκησέ',
#   'Ἐπακούσαι',
#   '',
#   'ἐκύκλωσάν',
#   'διαφορὰ',
#   'αἰτήματά',
#   'ἐπικαλεσώμεθά',
#   'εὐφρανεῖς',
#   'ἀντιλάβοιτό',
#   'γίνεσθαί',
#   'μισοῦντάς',
#   'φώτισόν',
#   'παρίδῃς',
#   'κατεπλάγη',
#   'Μαθήτριαι',
#   'αἰνετὸν',
#   'Καταξίωσον',
#   'ἥμαρτόν',
#   'καταφυγὴ',
#   'Πρόσδεξαι',
#   'ἀνόμημά',
#   'ἀήττητον',
#   'τρόπαιον',
#   'Προστασία',
#   'ἀκαταίσχυντε',
#   'παρίδῃς',
#   'ἱκεσίας',
#   'πανύμνητε',
#   'ἐνηχοῦντο',
#   'τρανῶς',
#   'θρηνολογοῦσαι',
#   'ᾔσθητε',
#   'Μυροφόροις',
#   'κιρνᾶτε',
#   'προσεφθέγγετο',
#   'Ἱδρωσάτω'])

# %%
def produce_material(output_file_name, data=None, blanks=None):
    if type(output_file_name) is not str:
        raise TypeError("variable 'output_file_name' must be of type 'str'.")

    if (data is not None) and (data != []): 
        for item in data:
            if item[0] is not None:

                print(item[1])

                curr = item[2]
                concordances = curr["concordances"]

                dc = {
                    "word": clean_up(concordances["Original Word"]),
                    "phonetics": concordances["Phonetic Spelling"],
                    "category": concordances["Part of Speech"],
                    "meaning": concordances['Definition'],
                    "greek": fetch_group_as_string([tuple[0] for tuple in curr['examples']], single_list=True),
                    "english": fetch_group_as_string([tuple[1] for tuple in curr['examples']], single_list=True)
                }
                dc["context"] = ""
                dc["original"] = item[1]        
                dc["source"] = item[0]        
                # to display which word is being worked upon at the time

                words_dataframe = pd.DataFrame.from_dict(dc, orient="index")
                words_dataframe = words_dataframe.transpose()
                words_dataframe.to_csv(os.path.join("output", output_file_name+".csv"), 
                                                    encoding="utf-8", mode="a", 
                                                    header=False, index=False)
            
    if (blanks is not None) and (blanks != []):
        blanks_dataframe = pd.DataFrame(blanks)
        blanks_dataframe= blanks_dataframe.transpose()
        blanks_dataframe.to_csv(os.path.join("blanks", output_file_name+"_blanks.csv"), 
                                            encoding="utf-8", mode="a", 
                                            header=False, index=False)

produce_material("blanks", data=data, blanks=blanks)
# Out:
# ἀνέπεμψα
# εὐαγγελίου
# ἀπέχῃς
# ἐλλόγει
# ἀποτίσω
# νῶτον
# εἶπα
# φθεγγομένου

# %%
d = acquire_data(reworked_fwl[0:6])
# Out:
# word no. 1: παιδοφθορήσεις
# word no. 2: ('μνησικακήσεις', 'μνησικακέω')
# word no. 3: ('διγνώμων', 'δίγνωμος')
# word no. 4: πονηρὰν
# word no. 5: ῷος
# word no. 6: παιδοφθορήσεις

# %%
d
# Out:
# ([],
#  ['παιδοφθορήσεις',
#   'μνησικακήσεις',
#   'διγνώμων',
#   'πονηρὰν',
#   'ῷος',
#   'παιδοφθορήσεις'])

# %%
produce_material("didache", d)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-2f0a5bbe466a> in <module>()
# ----> 1 produce_material("didache", d)
#
# <ipython-input-16-40f18ddb2dc7> in produce_material(output_file_name, data, blanks)
#       6     if (data is not None) and (data != []):
#       7         for item in data:
# ----> 8             if item[0] is not None:
#       9
#      10                 print(item[1])
#
# IndexError: list index out of range

# %%
for item in d:
    print(item)
    print(item)
# Out:
# [('BibleHub', 'δύο', {'concordances': {'Original Word': 'δύο', 'Part of Speech': 'Adjective; Indeclinable Numeral (Adjective)', 'Transliteration': 'duo', 'Phonetic Spelling': "(doo'-o)", 'Definition': 'two', 'Usage': 'two.'}, 'examples': [('εἶδεν ἄλλους δύο ἀδελφούς Ἰάκωβον', ' he saw others two brothers James'), ("μετ' αὐτοῦ δύο ", ' with him two'), ('Οὐδεὶς δύναται δυσὶ κυρίοις δουλεύειν', ' No one is able two masters to serve')]}), ('BibleHub', 'ἱμάτιόν', {'concordances': {'Original Word': 'ἱμάτιον, ου, τό', 'Part of Speech': 'Noun, Neuter', 'Transliteration': 'himation', 'Phonetic Spelling': "(him-at'-ee-on)", 'Definition': 'an outer garment, a cloak, robe', 'Usage': ' a long flowing outer garment, tunic.'}, 'examples': [('ἀγνάφου ἐπὶ ἱματίῳ παλαιῷ αἴρει', ' unshrunk on clothing old tears away'), ('ἀπὸ τοῦ ἱματίου καὶ χεῖρον', ' from the garment and a worse'), ('κρασπέδου τοῦ ἱματίου αὐτοῦ ', ' fringe of the clothing of him')]}), ('BibleHub', 'χιτῶνα', {'concordances': {'Original Word': 'χιτών, ῶνος, ὁ', 'Part of Speech': 'Noun, Masculine', 'Transliteration': 'chitón', 'Phonetic Spelling': "(khee-tone')", 'Definition': 'a tunic', 'Usage': 'a tunic, garment, undergarment.'}, 'examples': [('μηδὲ δύο χιτῶνας μηδὲ ὑποδήματα', ' nor two tunics nor sandals'), ('ἐνδύσησθε δύο χιτῶνας ', ' put on two tunics'), ('διαρρήξας τοὺς χιτῶνας αὐτοῦ λέγει', ' having torn the garments of him says')]}), ('BibleHub', 'λάβῃ', {'concordances': {'Original Word': 'λαμβάνω', 'Part of Speech': 'Verb', 'Transliteration': 'lambanó', 'Phonetic Spelling': "(lam-ban'-o)", 'Definition': 'to take, receive', 'Usage': '(a) I receive, get, (b) I take, lay hold of.'}, 'examples': [('ὁ αἰτῶν λαμβάνει καὶ ὁ', ' who asks receives and he that'), ('ἀσθενείας ἡμῶν ἔλαβεν καὶ τὰς', ' infirmities of us he took and our'), ('ἐκβάλλετε δωρεὰν ἐλάβετε δωρεὰν δότε', ' cast out freely you received freely give')]}), ('BibleHub', 'οὐδὲ', {'concordances': {'Original Word': 'οὐδέ', 'Part of Speech': 'Conjunction,Negative', 'Transliteration': 'oude', 'Phonetic Spelling': "(oo-deh')", 'Definition': 'and not, neither', 'Usage': 'neither, nor, not even, and not.'}, 'examples': [('παραπτώματα αὐτῶν οὐδὲ ὁ πατὴρ', ' trespasses of them neither the Father'), ('οὐ διορύσσουσιν οὐδὲ κλέπτουσιν ', ' not do break in nor steal'), ('οὐ σπείρουσιν οὐδὲ θερίζουσιν οὐδὲ', ' not they sow nor do they reap nor')]}), ('BibleHub', 'Παντὶ', {'concordances': {'Original Word': 'πᾶς, πᾶσα, πᾶν', 'Part of Speech': 'Adjective', 'Transliteration': 'pas', 'Phonetic Spelling': '(pas)', 'Definition': 'all, every', 'Usage': 'all, the whole, every kind of.'}, 'examples': [("ἐταράχθη καὶ πᾶσα Ἰεροσόλυμα μετ'", ' he was troubled and all Jerusalem with'), ('καὶ συναγαγὼν πάντας τοὺς ἀρχιερεῖς', ' And having gathered together all the chief priests'), ('ἀποστείλας ἀνεῖλεν πάντας τοὺς παῖδας', ' having sent forth he put to death all the boys')]})]
# [('BibleHub', 'δύο', {'concordances': {'Original Word': 'δύο', 'Part of Speech': 'Adjective; Indeclinable Numeral (Adjective)', 'Transliteration': 'duo', 'Phonetic Spelling': "(doo'-o)", 'Definition': 'two', 'Usage': 'two.'}, 'examples': [('εἶδεν ἄλλους δύο ἀδελφούς Ἰάκωβον', ' he saw others two brothers James'), ("μετ' αὐτοῦ δύο ", ' with him two'), ('Οὐδεὶς δύναται δυσὶ κυρίοις δουλεύειν', ' No one is able two masters to serve')]}), ('BibleHub', 'ἱμάτιόν', {'concordances': {'Original Word': 'ἱμάτιον, ου, τό', 'Part of Speech': 'Noun, Neuter', 'Transliteration': 'himation', 'Phonetic Spelling': "(him-at'-ee-on)", 'Definition': 'an outer garment, a cloak, robe', 'Usage': ' a long flowing outer garment, tunic.'}, 'examples': [('ἀγνάφου ἐπὶ ἱματίῳ παλαιῷ αἴρει', ' unshrunk on clothing old tears away'), ('ἀπὸ τοῦ ἱματίου καὶ χεῖρον', ' from the garment and a worse'), ('κρασπέδου τοῦ ἱματίου αὐτοῦ ', ' fringe of the clothing of him')]}), ('BibleHub', 'χιτῶνα', {'concordances': {'Original Word': 'χιτών, ῶνος, ὁ', 'Part of Speech': 'Noun, Masculine', 'Transliteration': 'chitón', 'Phonetic Spelling': "(khee-tone')", 'Definition': 'a tunic', 'Usage': 'a tunic, garment, undergarment.'}, 'examples': [('μηδὲ δύο χιτῶνας μηδὲ ὑποδήματα', ' nor two tunics nor sandals'), ('ἐνδύσησθε δύο χιτῶνας ', ' put on two tunics'), ('διαρρήξας τοὺς χιτῶνας αὐτοῦ λέγει', ' having torn the garments of him says')]}), ('BibleHub', 'λάβῃ', {'concordances': {'Original Word': 'λαμβάνω', 'Part of Speech': 'Verb', 'Transliteration': 'lambanó', 'Phonetic Spelling': "(lam-ban'-o)", 'Definition': 'to take, receive', 'Usage': '(a) I receive, get, (b) I take, lay hold of.'}, 'examples': [('ὁ αἰτῶν λαμβάνει καὶ ὁ', ' who asks receives and he that'), ('ἀσθενείας ἡμῶν ἔλαβεν καὶ τὰς', ' infirmities of us he took and our'), ('ἐκβάλλετε δωρεὰν ἐλάβετε δωρεὰν δότε', ' cast out freely you received freely give')]}), ('BibleHub', 'οὐδὲ', {'concordances': {'Original Word': 'οὐδέ', 'Part of Speech': 'Conjunction,Negative', 'Transliteration': 'oude', 'Phonetic Spelling': "(oo-deh')", 'Definition': 'and not, neither', 'Usage': 'neither, nor, not even, and not.'}, 'examples': [('παραπτώματα αὐτῶν οὐδὲ ὁ πατὴρ', ' trespasses of them neither the Father'), ('οὐ διορύσσουσιν οὐδὲ κλέπτουσιν ', ' not do break in nor steal'), ('οὐ σπείρουσιν οὐδὲ θερίζουσιν οὐδὲ', ' not they sow nor do they reap nor')]}), ('BibleHub', 'Παντὶ', {'concordances': {'Original Word': 'πᾶς, πᾶσα, πᾶν', 'Part of Speech': 'Adjective', 'Transliteration': 'pas', 'Phonetic Spelling': '(pas)', 'Definition': 'all, every', 'Usage': 'all, the whole, every kind of.'}, 'examples': [("ἐταράχθη καὶ πᾶσα Ἰεροσόλυμα μετ'", ' he was troubled and all Jerusalem with'), ('καὶ συναγαγὼν πάντας τοὺς ἀρχιερεῖς', ' And having gathered together all the chief priests'), ('ἀποστείλας ἀνεῖλεν πάντας τοὺς παῖδας', ' having sent forth he put to death all the boys')]})]
# []
# []

# %%
data = d[0]
blanks = d[1]

# %%
for item in data:
    print(item[1])
# Out:
# δύο
# ἱμάτιόν
# χιτῶνα
# λάβῃ
# οὐδὲ
# Παντὶ

# %%
produce_material("didache", data, blanks)
# Out:
# δύο
# ἱμάτιόν
# χιτῶνα
# λάβῃ
# οὐδὲ
# Παντὶ

# %%
for item in data:
    c = wf.concordance_list(cltk_normalize(item[1]))
    line, bold = boldify_selected_word(cltk_normalize(item[1]), c[0][6])
    print(line, bold)
# Out:
# ['μετ', "'", 'αὐτοῦ', '<b>δύο</b>', ';', 'ἐὰν', 'ἄρῃ', 'τις', 'τὸ', 'ἱμάτιόν', 'σου', ',', 'δὸς', 'αὐ'] <b>δύο</b>
# ['μετ', "'", 'αὐτοῦ', 'δύο', ';', 'ἐὰν', 'ἄρῃ', 'τις', 'τὸ', '<b>ἱμάτιόν</b>', 'σου', ',', 'δὸς', 'αὐτῷ', 'καὶ', 'τὸν', 'χιτῶνα', ';', 'ἐὰν'] <b>ἱμάτιόν</b>
# ['ς', 'τὸ', 'ἱμάτιόν', 'σου', ',', 'δὸς', 'αὐτῷ', 'καὶ', 'τὸν', '<b>χιτῶνα</b>', ';', 'ἐὰν', 'λάβῃ', 'τις', 'ἀπὸ', 'σοῦ', 'τὸ', 'σόν', ',', 'μὴ'] <b>χιτῶνα</b>
# ['σου', ',', 'δὸς', 'αὐτῷ', 'καὶ', 'τὸν', 'χιτῶνα', ';', 'ἐὰν', '<b>λάβῃ</b>', 'τις', 'ἀπὸ', 'σοῦ', 'τὸ', 'σόν', ',', 'μὴ', 'ἀπαίτει', ';', 'οὐ'] <b>λάβῃ</b>
# ['βῃ', 'τις', 'ἀπὸ', 'σοῦ', 'τὸ', 'σόν', ',', 'μὴ', 'ἀπαίτει', ';', '<b>οὐδὲ</b>', 'γὰρ', 'δύνασαι', '.', 'Παντὶ', 'τῷ', 'αἰτοῦντί', 'σε', 'δ'] <b>οὐδὲ</b>
# ['όν', ',', 'μὴ', 'ἀπαίτει', ';', 'οὐδὲ', 'γὰρ', 'δύνασαι', '.', '<b>Παντὶ</b>', 'τῷ', 'αἰτοῦντί', 'σε', 'δίδου', 'καὶ', 'μὴ', 'ἀπαίτει'] <b>Παντὶ</b>
