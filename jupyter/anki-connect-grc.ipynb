# %%
# VER TODO-LIST em README.md
import json
import urllib.request
from toolset import (get_examples, get_frequency,
                    get_text, get_tokens)
from cltk import NLP
from cltk.lemmatize.grc import GreekBackoffLemmatizer
lemmatizer = GreekBackoffLemmatizer()

from cltk.alphabet.text_normalization import cltk_normalize

# %%
creed, wf = get_text("creed.txt")
tokens, token_set, phrases = get_tokens(creed)
frequency = get_frequency(tokens)
cltk_nlp = NLP(language="grc")
cltk_doc = cltk_nlp.analyze(creed)

wordlist = []
for pair in frequency:
    token = pair[0]
    wordlist.append(token)
# Out:
# ‎𐤀 CLTK version '1.0.25'.
# Pipeline for language 'Ancient Greek' (ISO: 'grc'): `GreekNormalizeProcess`, `GreekStanzaProcess`, `GreekEmbeddingsProcess`, `StopsProcess`, `GreekNERProcess`.

# %%
def request(action, **params):
    return {'action': action,
            'params': params,
            'version': 6}

def invoke(action, **params):
    requestJson = json.dumps(request(action, **params)).encode('utf-8')
    response = json.load(urllib.request.urlopen(urllib.request.Request('http://localhost:8765', requestJson)))

    if len(response) != 2:
        raise Exception('response has an unexpected number of fields')

    if 'error' not in response:
        raise Exception('response is missing required error field')
    
    if 'result' not in response:
        raise Exception('response is missing required result field')

    if response['error'] is not None:
        raise Exception(response['error'])

    return response['result']

noteIDs = invoke('findNotes', query='deck:Liturgia')
notesInfo = invoke('notesInfo', notes=noteIDs)

# %%
notes = []
for card in notesInfo:
    notes.append(cltk_normalize(card['fields']['Word']['value']))
fwl = [cltk_normalize(word) for word in wordlist if word not in notes]
notes_group = lemmatizer.lemmatize(notes)
fwl_group = lemmatizer.lemmatize(fwl)

# %%
notes_lemmas = set([tuple[1] for tuple in notes_group])
fwl_lemmas = set([tuple[1] for tuple in fwl_group])

# %%
filtered_fwl_lemmas = [word for word in fwl_lemmas if word not in notes_lemmas]
reworked_fwl = [tuple for tuple in fwl_group if tuple[1] in filtered_fwl_lemmas]

# %%
'''
Ok, o que fazer agora, então?

O que eu tenho que fazer é o seguinte:
1. pegar as palavras que estão dispostas acima
2. Procurar por elas em dois sites:
2.1. BibleHub
2.2. Wiktionary 
3. Se nada for encontrado, procurar pelos seus *lemas*
4. Se nada for encontrado, criar uma lista para procurar manualmente.
'''
# Out:
# '\nOk, o que fazer agora, então?\n\nO que eu tenho que fazer é o seguinte:\n1. pegar as palavras que estão dispostas acima\n2. Procurar por elas em dois sites:\n2.1. BibleHub\n2.2. Wiktionary \n3. Se nada for encontrado, procurar pelos seus *lemas*\n4. Se nada for encontrado, criar uma lista para procurar manualmente.\n'

# %%
from words import Word as WikWord
from scraper import Word as BibleWord
from scraper import get_link, get_entry_soup, get_word_data, fetch_group_as_string
from scraper import BASE_URL

# %%
# antes é necessário fazer com que as palavras idênticas aos seus 
# lemas não provoquem redundância, desfazendo as tuplas
# em uma string única

# %%
for i in range(len(reworked_fwl)):
#    for j in reworked_fwl[i]:
    if reworked_fwl[i][0] == reworked_fwl[i][1]:
        reworked_fwl[i] = reworked_fwl[i][0]

# %%
working = reworked_fwl[0]
# wword = WikWord(working)

# %%
def fetch_bible_word(word):
    link = get_link(BASE_URL, word)
    soup = get_entry_soup(link)
    word = BibleWord(get_word_data(soup))

    return word

# %%
from requests.exceptions import MissingSchema
# this can be further optimized by instead of summing up the searches
# isolating the searches according to the site used to search


def double_searcher(word):
    if type(word) == tuple:
        try:
            bible_word = fetch_bible_word(word[0])
            return 1, 0, "Bible", word[0], bible_word.data

        except MissingSchema:
            try:
                bible_word = fetch_bible_word(word[1])
                return 2, 0, "Bible", word[0], bible_word.data

            except MissingSchema:
                wik_word = WikWord(word[0])
                if (not wik_word.definitions) or (wik_word.defintions == []):
                        wik_word = WikWord(word[1])
                        return 2, 2, "Wik", word[1], wik_word
                return 2, 1, "Wik", word[1], wik_word

    elif type(word) == str:
        try: 
            bible_word = fetch_bible_word(word)
            return 1, 0, "Bible", word, bible_word.data

        except:
            try:
                wik_word = WikWord(word)
                return 1, 1, "Wik", word, wik_word
            except:
                return 1, 1, False, word

    else:
        return 0, 0, 0, False

# %%
def searcher(word):
    if type(word) == tuple:
        try:
            bible_word = fetch_bible_word(word[0])
            return 1, "Bible", word[0], bible_word.data

        except MissingSchema:
            try:
                bible_word = fetch_bible_word(word[1])
                return 2, "Bible", word[0], bible_word.data

            except MissingSchema:

                return 2, False, word[0]
                

    elif type(word) == str:
        try: 
            bible_word = fetch_bible_word(word)
            return 1, "Bible", word, bible_word.data

        except:
                return 1, False, word

    else:
        return 0, False, word

# %%
reworked_fwl = reworked_fwl[29:]

# %%
reworked_fwl
# Out:
# [('ἐνανθρωπήσαντα', 'ἐνανθρωπέω'),
#  'Σταυρωθέντα',
#  ('ὑπὲρ', 'ὑπέρ'),
#  'Ποντίου',
#  'Πιλάτου',
#  ('παθόντα', 'πάσχω'),
#  ('ταφέντα', 'θάπτω'),
#  ('ἀναστάντα', 'ἀνίστημι'),
#  ('τρίτῃ', 'τρίτος'),
#  'Γραφάς',
#  ('ἀνελθόντα', 'ἀνέρχομαι'),
#  'οὐρανοὺς',
#  ('καθεζόμενον', 'κατάἕζομαι'),
#  'πάλιν',
#  ('μετὰ', 'μετά'),
#  ('κρῖναι', 'κρίνω'),
#  ('ζῶντας', 'ζάω'),
#  ('νεκρούς', 'νεκρός'),
#  ('βασιλείας', 'βασιλεία'),
#  ('οὐκ', 'οὐ'),
#  'τέλος',
#  'Πνεῦμα',
#  'Ἅγιον',
#  ('ζωοποιόν', 'ζωοποιός'),
#  ('ἐκπορευόμενον', 'ἐκπορεύω'),
#  ('σὺν', 'σύν'),
#  'Πατρὶ',
#  'Υἱῷ',
#  ('συμπροσκυνούμενον', 'σύν,πρόσκυνάω'),
#  ('συνδοξαζόμενον', 'συνδοξάζω'),
#  ('λαλῆσαν', 'λαλέω'),
#  'Προφητῶν',
#  'Εἰς',
#  ('μίαν', 'εἷς'),
#  ('ἁγίαν', 'ἅγιος'),
#  'καθολικὴν',
#  'ἀποστολικὴν',
#  'Ἐκκλησίαν',
#  'Ὁμολογῶ',
#  ('ἓν', 'εἷς'),
#  'βάπτισμα',
#  ('ἄφεσιν', 'ἄφεσις'),
#  'Προσδοκῶ',
#  ('ἀνάστασιν', 'ἀνάστασις'),
#  ('νεκρῶν', 'νεκρός'),
#  ('μέλλοντος', 'μέλλω'),
#  'Ἀμήν',
#  ('ἕνα', 'εἷς'),
#  'τε',
#  ('πάντων', 'πᾶς'),
#  'Θεοῦ',
#  'Πατρὸς',
#  ('γεννηθέντα', 'γεννάω'),
#  'δι ̓',
#  ('οὗ', 'ἵημι'),
#  'ἐκ']

# %%
bible_searches = 0
wiki_searches = 0
data = []
blanks = []
import time

for index in range(len(reworked_fwl)):
    print("word no. {}: {}".format(index, reworked_fwl[index]))
    a = searcher(reworked_fwl[index])
    if a[1] != False:
        data.append((a[1], a[2], a[3]))
    else:
        blanks.append(a[2])
    bible_searches += a[0]
    if bible_searches >= 10:
        for n in range(60):
            time.sleep(1)
            print("Wait... {}/60".format(n))
            bible_searches = 0
"""
for index in range(len(reworked_fwl)):
    print("word no. {}".format(index))
    a = double_searcher(reworked_fwl[index])
    data.append((a[2], a[3], a[4]))
    bible_searches += a[0]
    wiki_searches += a[1]
    if bible_searches >= 10:
        for n in range(60):
            time.sleep(1)
            print("Wait... {}/60".format(n))
            bible_searches = 0
    if wiki_searches >= 10:
        for n in range(60):
            time.sleep(1)
            print("Wait... {}/60".format(n))
            wiki_searches = 0
"""
# Out:
# word no. 0: ('ἐνανθρωπήσαντα', 'ἐνανθρωπέω')
# word no. 1: Σταυρωθέντα
# word no. 2: ('ὑπὲρ', 'ὑπέρ')
# word no. 3: Ποντίου
# word no. 4: Πιλάτου
# word no. 5: ('παθόντα', 'πάσχω')
# word no. 6: ('ταφέντα', 'θάπτω')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 7: ('ἀναστάντα', 'ἀνίστημι')
# word no. 8: ('τρίτῃ', 'τρίτος')
# word no. 9: Γραφάς
# word no. 10: ('ἀνελθόντα', 'ἀνέρχομαι')
# word no. 11: οὐρανοὺς
# word no. 12: ('καθεζόμενον', 'κατάἕζομαι')
# word no. 13: πάλιν
# word no. 14: ('μετὰ', 'μετά')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 15: ('κρῖναι', 'κρίνω')
# word no. 16: ('ζῶντας', 'ζάω')
# word no. 17: ('νεκρούς', 'νεκρός')
# word no. 18: ('βασιλείας', 'βασιλεία')
# word no. 19: ('οὐκ', 'οὐ')
# word no. 20: τέλος
# word no. 21: Πνεῦμα
# word no. 22: Ἅγιον
# word no. 23: ('ζωοποιόν', 'ζωοποιός')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 24: ('ἐκπορευόμενον', 'ἐκπορεύω')
# word no. 25: ('σὺν', 'σύν')
# word no. 26: Πατρὶ
# word no. 27: Υἱῷ
# word no. 28: ('συμπροσκυνούμενον', 'σύν,πρόσκυνάω')
# word no. 29: ('συνδοξαζόμενον', 'συνδοξάζω')
# word no. 30: ('λαλῆσαν', 'λαλέω')
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 31: Προφητῶν
# word no. 32: Εἰς
# word no. 33: ('μίαν', 'εἷς')
# word no. 34: ('ἁγίαν', 'ἅγιος')
# word no. 35: καθολικὴν
# word no. 36: ἀποστολικὴν
# word no. 37: Ἐκκλησίαν
# word no. 38: Ὁμολογῶ
# word no. 39: ('ἓν', 'εἷς')
# word no. 40: βάπτισμα
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 41: ('ἄφεσιν', 'ἄφεσις')
# word no. 42: Προσδοκῶ
# word no. 43: ('ἀνάστασιν', 'ἀνάστασις')
# word no. 44: ('νεκρῶν', 'νεκρός')
# word no. 45: ('μέλλοντος', 'μέλλω')
# word no. 46: Ἀμήν
# word no. 47: ('ἕνα', 'εἷς')
# word no. 48: τε
# word no. 49: ('πάντων', 'πᾶς')
# word no. 50: Θεοῦ
# Wait... 0/60
# Wait... 1/60
# Wait... 2/60
# Wait... 3/60
# Wait... 4/60
# Wait... 5/60
# Wait... 6/60
# Wait... 7/60
# Wait... 8/60
# Wait... 9/60
# Wait... 10/60
# Wait... 11/60
# Wait... 12/60
# Wait... 13/60
# Wait... 14/60
# Wait... 15/60
# Wait... 16/60
# Wait... 17/60
# Wait... 18/60
# Wait... 19/60
# Wait... 20/60
# Wait... 21/60
# Wait... 22/60
# Wait... 23/60
# Wait... 24/60
# Wait... 25/60
# Wait... 26/60
# Wait... 27/60
# Wait... 28/60
# Wait... 29/60
# Wait... 30/60
# Wait... 31/60
# Wait... 32/60
# Wait... 33/60
# Wait... 34/60
# Wait... 35/60
# Wait... 36/60
# Wait... 37/60
# Wait... 38/60
# Wait... 39/60
# Wait... 40/60
# Wait... 41/60
# Wait... 42/60
# Wait... 43/60
# Wait... 44/60
# Wait... 45/60
# Wait... 46/60
# Wait... 47/60
# Wait... 48/60
# Wait... 49/60
# Wait... 50/60
# Wait... 51/60
# Wait... 52/60
# Wait... 53/60
# Wait... 54/60
# Wait... 55/60
# Wait... 56/60
# Wait... 57/60
# Wait... 58/60
# Wait... 59/60
# word no. 51: Πατρὸς
# word no. 52: ('γεννηθέντα', 'γεννάω')
# word no. 53: δι ̓
# word no. 54: ('οὗ', 'ἵημι')
# word no. 55: ἐκ
# '\nfor index in range(len(reworked_fwl)):\n    print("word no. {}".format(index))\n    a = double_searcher(reworked_fwl[index])\n    data.append((a[2], a[3], a[4]))\n    bible_searches += a[0]\n    wiki_searches += a[1]\n    if bible_searches >= 10:\n        for n in range(60):\n            time.sleep(1)\n            print("Wait... {}/60".format(n))\n            bible_searches = 0\n    if wiki_searches >= 10:\n        for n in range(60):\n            time.sleep(1)\n            print("Wait... {}/60".format(n))\n            wiki_searches = 0\n'

# %%
data[-5:]
# Out:
# [('Bible',
#   'Πατρὸς',
#   {'concordances': {'Original Word': 'πατήρ, πατρός, ὁ',
#     'Part of Speech': 'Noun, Masculine',
#     'Transliteration': 'patér',
#     'Phonetic Spelling': "(pat-ayr')",
#     'Definition': 'a father',
#     'Usage': 'father, (Heavenly) Father, ancestor, elder, senior.'},
#    'examples': [('ἐν ἑαυτοῖς Πατέρα ἔχομεν τὸν',
#      ' within yourselves [For] father we have'),
#     ('Ζεβεδαίου τοῦ πατρὸς αὐτῶν καταρτίζοντας',
#      ' Zebedee the father of them mending'),
#     ('καὶ τὸν πατέρα αὐτῶν ἠκολούθησαν',
#      ' and the father of them they followed')]}),
#  ('Bible',
#   'γεννηθέντα',
#   {'concordances': {'Original Word': 'γεννάω',
#     'Part of Speech': 'Verb',
#     'Transliteration': 'gennaó',
#     'Phonetic Spelling': "(ghen-nah'-o)",
#     'Definition': 'to beget, to bring forth',
#     'Usage': 'I beget (of the male), (of the female) I bring forth, give birth to.'},
#    'examples': [('Ἰσαὰκ δὲ ἐγέννησεν τὸν Ἰακώβ',
#      ' Isaac moreover was father of Jacob'),
#     ('Ἰακὼβ δὲ ἐγέννησεν τὸν Ἰούδαν', ' Jacob moreover was father of Judah'),
#     ('Ἰούδας δὲ ἐγέννησεν τὸν Φαρὲς',
#      ' Judah moreover was father of Perez')]}),
#  ('Bible',
#   'δι ̓',
#   {'concordances': {'Original Word': 'αἰτία, ας, ἡ',
#     'Part of Speech': 'Noun, Feminine',
#     'Transliteration': 'aitia',
#     'Phonetic Spelling': "(ahee-tee'-a)",
#     'Definition': 'cause, reason',
#     'Usage': 'a cause, reason, excuse; a charge, accusation; guilt; circumstances, case.'},
#    'examples': [('ἐστὶν ἡ αἰτία τοῦ ἀνθρώπου', ' is the case of the man'),
#     ('αὐτοῦ τὴν αἰτίαν αὐτοῦ γεγραμμένην',
#      ' of him the accusation of him written'),
#     ('ἐπιγραφὴ τῆς αἰτίας αὐτοῦ ἐπιγεγραμμένη',
#      ' inscription of the accusation against him read')]}),
#  ('Bible',
#   'οὗ',
#   {'concordances': {'Original Word': 'οὗ',
#     'Part of Speech': 'Adverb',
#     'Transliteration': 'hou',
#     'Phonetic Spelling': '(hoo)',
#     'Definition': 'where (adv. of place)',
#     'Usage': 'where, whither, when, in what place.'},
#    'examples': [('οὗ γάρ εἰσιν', ' where indeed are'),
#     ('τὸ ὄρος οὗ ἐτάξατο αὐτοῖς', ' the mountain where appointed them'),
#     ('εἰς Ναζαρά οὗ ἦν τεθραμμένος',
#      ' to Nazareth where he was brought up')]}),
#  ('Bible',
#   'ἐκ',
#   {'concordances': {'Original Word': 'ἐκ, ἐξ',
#     'Part of Speech': 'Preposition',
#     'Transliteration': 'ek or ex',
#     'Phonetic Spelling': '(ek)',
#     'Definition': 'from, from out of',
#     'Usage': 'from out, out from among, from, suggesting from the interior outwards.'},
#    'examples': [('τὸν Βοὲς ἐκ τῆς Ῥαχάβ', ' Boaz of Rahab'),
#     ('τὸν Ἰωβὴδ ἐκ τῆς Ῥούθ', ' Obed of Ruth'),
#     ('τὸν Σολομῶνα ἐκ τῆς τοῦ', ' Solomon of the one [who had been wife]')]})]

# %%
werd = data[-3]
b = clean_up(werd[1])
c = b.split()[0]
wf.concordance_list(c)
# Out:
# []

# %%
import pandas as pd
for item in data[-3:]:
    if item[0] == "Bible":

        print(item[1])

        curr = item[2]
        concordances = curr["concordances"]

        dc = {
            "word": concordances["Original Word"],
            "phonetics": concordances["Phonetic Spelling"],
            "category": concordances["Part of Speech"],
            "meaning": concordances['Definition'],
            "greek": fetch_group_as_string([tuple[0] for tuple in curr['examples']], single_list=True),
            "english": fetch_group_as_string([tuple[1] for tuple in curr['examples']], single_list=True),
        }

        try:
            dc["context"] = get_context_example(item[1].split()[0], wf)
        except IndexError:
            print("word \"{}\" could not be contextualized".format(item[1]))
        
        # to display which word is being worked upon at the time

        words_dataframe = pd.DataFrame.from_dict(dc, orient="index")
        words_dataframe = words_dataframe.transpose()
        words_dataframe.to_csv("greek_output.csv", encoding="utf-8", mode="a", header=False, index=False)
# Out:
# δι ̓
# word "{}" could not be contextualized
# οὗ
# ἐκ

# %%
import re
curr_d = data[0][1]
word_name = curr_d['concordances']['Original Word']
concordance = wf.concordance_list(word_name)[0][6]
cleaned_up = re.sub(r'\s([?.!,:;"](?:\s|$))', r'\1', concordance)
pattern = r"^\s+"
cleaned_up = re.sub(pattern,"",cleaned_up)
cleaned_up
# Out:
# 'Πιστεύω εἰς ἕνα Θεόν, Πατέρα, παντοκράτορ'

# %%
# ways to perfect this function:
# check whether the first word in the concordance example is it
# if not, cut off this word (so as to remove incomplete words)
# do the same to the last word of the sentence
def get_context_example(word, concordance):
    """
    for the purpose of getting an example of the word in question
    being used in context, and cleaning up this example 
    (because NLTK adds a lot of trailing spaces and separates words
    from punctuation signals in the string itself)
    """
    trailing_spaces_start = r"^\s+"
    trailing_spaces_end = r"\s+$"

    context = concordance.concordance_list(word.split()[0])[0][6]
    cleaned_up_pre = re.sub(r'\s([?.!,:;"](?:\s|$))', r'\1', context)
    cleaned_up_start = re.sub(trailing_spaces_start, "", cleaned_up_pre)
    cleaned_up = re.sub(trailing_spaces_end, "", cleaned_up_start)

    return cleaned_up

def clean_up(string):
    trailing_spaces_start = r"^\s+"
    trailing_spaces_end = r"\s+$"

    cleaned_up_pre = re.sub(r'\s([?.!,:;"](?:\s|$))', r'\1', string)
    cleaned_up_start = re.sub(trailing_spaces_start, "", cleaned_up_pre)
    cleaned_up = re.sub(trailing_spaces_end, "", cleaned_up_start)

    return cleaned_up

# %%
b = get_context_example(reworked_fwl[0][0], wf)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-168-c21b6ea205b4> in <module>
# ----> 1 b = get_context_example(dc['word'], wf)
#
# <ipython-input-141-796c7892fc17> in get_context_example(word, concordance)
#      13     trailing_spaces_end = r"\s+$"
#      14
# ---> 15     context = concordance.concordance_list(word)[0][6]
#      16     cleaned_up_pre = re.sub(r'\s([?.!,:;"](?:\s|$))', r'\1', context)
#      17     cleaned_up_start = re.sub(trailing_spaces_start, "", cleaned_up_pre)
#
# IndexError: list index out of range

# %%
wf.concordance_list(dc['word'].split()[0].split(",")[0])
# Out:
# []

# %%
get_context_example(dc['word'].split()[0].split(",")[0],wf)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-184-e7b367d369a6> in <module>
# ----> 1 get_context_example(dc['word'].split()[0].split(",")[0],wf)
#
# <ipython-input-175-471c8a230b5b> in get_context_example(word, concordance)
#      13     trailing_spaces_end = r"\s+$"
#      14
# ---> 15     context = concordance.concordance_list(word.split()[0])[0][6]
#      16     cleaned_up_pre = re.sub(r'\s([?.!,:;"](?:\s|$))', r'\1', context)
#      17     cleaned_up_start = re.sub(trailing_spaces_start, "", cleaned_up_pre)
#
# IndexError: list index out of range

# %%
# what I must get is not the word from bibleHub, but take that from it from BibleHub
# and then use the very word to look for examples in the concordance
data
# Out:
# [('Bible',
#   {'concordances': {'Original Word': 'πιστεύω',
#     'Part of Speech': 'Verb',
#     'Transliteration': 'pisteuó',
#     'Phonetic Spelling': "(pist-yoo'-o)",
#     'Definition': 'to believe, entrust',
#     'Usage': 'I believe, have faith in, trust in; pass: I am entrusted with.'},
#    'examples': [('ὁ Ἰησοῦς Πιστεύετε ὅτι δύναμαι',
#      ' Jesus Believe you that I am able'),
#     ('τούτων τῶν πιστευόντων εἰς ἐμέ', ' of these who believe in me'),
#     ('τῇ προσευχῇ πιστεύοντες λήμψεσθε ',
#      ' prayer believing you will receive')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'θεός, οῦ, ὁ',
#     'Part of Speech': 'Noun, Feminine; Noun, Masculine',
#     'Transliteration': 'theos',
#     'Phonetic Spelling': "(theh'-os)",
#     'Definition': 'God, a god',
#     'Usage': '(a) God, (b) a god, generally.'},
#    'examples': [('δύναται ὁ θεὸς ἐκ τῶν', ' able is God from the'),
#     ('πνεῦμα τοῦ θεοῦ καταβαῖνον ὡσεὶ', ' Spirit of God descending as'),
#     ('εἶ τοῦ θεοῦ εἰπὲ ἵνα', ' you are of God speak that')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'τιμάω',
#     'Part of Speech': 'Verb',
#     'Transliteration': 'timaó',
#     'Phonetic Spelling': "(tim-ah'-o)",
#     'Definition': 'to fix the value, to price',
#     'Usage': '(a) I value at a price, estimate, (b) I honor, reverence.'},
#    'examples': [('οὐ μὴ τιμήσει τὸν πατέρα',
#      ' no not he should honor the father'),
#     ('χείλεσίν με τιμᾷ ἡ δὲ', ' lips me it honors with the moreover'),
#     ('Τίμα τὸν πατέρα', ' Honor the Father')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'ποιητής, οῦ, ὁ',
#     'Part of Speech': 'Noun, Masculine',
#     'Transliteration': 'poiétés',
#     'Phonetic Spelling': "(poy-ay-tace')",
#     'Definition': 'a maker, a doer',
#     'Usage': '(a) a maker, poet, (b) a doer, carrier out, performer.'},
#    'examples': [("ἀλλ' οἱ ποιηταὶ νόμου δικαιωθήσονται",
#      ' but the doers of the law will be justified'),
#     ('Γίνεσθε δὲ ποιηταὶ λόγου καὶ',
#      ' be you moreover doers of [the] word and'),
#     ('καὶ οὐ ποιητής οὗτος ἔοικεν', ' and not a doer this one is like')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'ὁρατός, ή, όν',
#     'Part of Speech': 'Adjective',
#     'Transliteration': 'horatos',
#     'Phonetic Spelling': "(hor-at-os')",
#     'Definition': 'visible',
#     'Usage': 'visible.'},
#    'examples': []}),
#  ('Bible',
#   {'concordances': {'Original Word': 'ἀόρατος, ον',
#     'Part of Speech': 'Adjective',
#     'Transliteration': 'aoratos',
#     'Phonetic Spelling': "(ah-or'-at-os)",
#     'Definition': 'invisible',
#     'Usage': 'unseen, invisible.'},
#    'examples': [('θεοῦ τοῦ ἀοράτου πρωτότοκος πάσης',
#      ' God invisible [the] firstborn of all'),
#     ('καὶ τὰ ἀόρατα εἴτε θρόνοι', ' and the invisible whether thrones'),
#     ('αἰώνων ἀφθάρτῳ ἀοράτῳ μόνῳ θεῷ',
#      ' ages [the] immortal invisible only God')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'κύριος, ου, ὁ',
#     'Part of Speech': 'Noun, Masculine',
#     'Transliteration': 'kurios',
#     'Phonetic Spelling': "(koo'-ree-os)",
#     'Definition': 'lord, master',
#     'Usage': 'lord, master, sir; the Lord.'},
#    'examples': [('ῥηθὲν ὑπὸ Κυρίου διὰ τοῦ',
#      ' having been spoken by the Lord through the'),
#     ('ὁ ἄγγελος Κυρίου καὶ παρέλαβεν',
#      ' the angel of [the] Lord and took to [him]'),
#     ("ἰδοὺ ἄγγελος Κυρίου φαίνεται κατ'",
#      ' behold an angel of [the] Lord appears in')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'Ἰησοῦς, οῦ, ὁ',
#     'Part of Speech': 'Noun, Masculine',
#     'Transliteration': 'Iésous',
#     'Phonetic Spelling': "(ee-ay-sooce')",
#     'Definition': 'Jesus or Joshua, the name of the Messiah, also three other Isr',
#     'Usage': 'Jesus; the Greek form of Joshua; Jesus, son of Eliezer; Jesus, surnamed Justus.'},
#    'examples': [('ἧς ἐγεννήθη Ἰησοῦς ὁ λεγόμενος',
#      ' whom was born Jesus who is called'),
#     ('ΤΟΥ ΔΕ ΙΗΣΟΥ ΧΡΙΣΤΟΥ ἡ', ' now of Jesus Christ the'),
#     ('ὄνομα αὐτοῦ Ἰησοῦν αὐτὸς γὰρ', ' name of him Jesus he indeed')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'Χριστός, οῦ, ὁ',
#     'Part of Speech': 'Noun, Masculine',
#     'Transliteration': 'Christos',
#     'Phonetic Spelling': "(khris-tos')",
#     'Definition': 'the Anointed One, Messiah, Christ',
#     'Usage': 'Anointed One; the Messiah, the Christ.'},
#    'examples': [('ὁ λεγόμενος Χριστός ', ' who is called Christ'),
#     ('ἕως τοῦ χριστοῦ γενεαὶ δεκατέσσαρες',
#      ' to the Christ generations fourteen'),
#     ('ΔΕ ΙΗΣΟΥ ΧΡΙΣΤΟΥ ἡ γένεσις', ' now of Jesus Christ the birth')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'υἱός, οῦ, ὁ',
#     'Part of Speech': 'Noun, Masculine',
#     'Transliteration': 'huios',
#     'Phonetic Spelling': "(hwee-os')",
#     'Definition': 'a son',
#     'Usage': 'a son, descendent.'},
#    'examples': [('υἱοῦ Δαυὶδ υἱοῦ Ἀβραάμ ', ' son of David son of Abraham'),
#     ('λέγων Ἰωσὴφ υἱὸς Δαυίδ μὴ', ' saying Joseph son of David not'),
#     ('τέξεται δὲ υἱὸν καὶ καλέσεις',
#      ' she will bear moreover a son and you will call')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'πρό',
#     'Part of Speech': 'Preposition',
#     'Transliteration': 'pro',
#     'Phonetic Spelling': '(pro)',
#     'Definition': 'before',
#     'Usage': '(a) of place: before, in front of, (b) of time: before, earlier than.'},
#    'examples': [('χρείαν ἔχετε πρὸ τοῦ ὑμᾶς', ' need you have before you'),
#     ('ἦλθες ὧδε πρὸ καιροῦ βασανίσαι',
#      ' are you come here before [the] time to torment'),
#     ('ἄγγελόν μου πρὸ προσώπου σου',
#      ' messenger of me before [the] face of you')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'φῶς, φωτός, τό',
#     'Part of Speech': 'Noun, Neuter',
#     'Transliteration': 'phós',
#     'Phonetic Spelling': '(foce)',
#     'Definition': 'light',
#     'Usage': 'light, a source of light, radiance.'},
#    'examples': [('σκιᾷ θανάτου φῶς ἀνέτειλεν αὐτοῖς',
#      ' shadow of death a light has dawned on them'),
#     ('ἐστὲ τὸ φῶς τοῦ κόσμου', ' are the light of the world'),
#     ('λαμψάτω τὸ φῶς ὑμῶν ἔμπροσθεν', ' let shine the light of you before')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'δοξάζω',
#     'Part of Speech': 'Verb',
#     'Transliteration': 'doxazó',
#     'Phonetic Spelling': "(dox-ad'-zo)",
#     'Definition': 'to render or esteem glorious (in a wide application)',
#     'Usage': 'I glorify, honor, bestow glory on.'},
#    'examples': [('ῥύμαις ὅπως δοξασθῶσιν ὑπὸ τῶν',
#      ' streets that they might have glory from the'),
#     ('ἐφοβήθησαν καὶ ἐδόξασαν τὸν θεὸν', ' marveled and glorified God'),
#     ('βλέποντας καὶ ἐδόξασαν τὸν θεὸν',
#      ' seeing and they glorified the God')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'ἀληθινός, η, ον',
#     'Part of Speech': 'Adjective',
#     'Transliteration': 'aléthinos',
#     'Phonetic Spelling': "(al-ay-thee-nos')",
#     'Definition': 'TRUE',
#     'Usage': 'true (lit: made of truth), real, genuine.'},
#    'examples': [('φῶς τὸ ἀληθινὸν ὃ φωτίζει',
#      ' light true that which enlightens'),
#     ('ὅτε οἱ ἀληθινοὶ προσκυνηταὶ προσκυνήσουσιν',
#      ' when the true worshippers will worship'),
#     ('λόγος ἐστὶν ἀληθινὸς ὅτι ἄλλος', ' saying is true That one')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'ἀληθινός, η, ον',
#     'Part of Speech': 'Adjective',
#     'Transliteration': 'aléthinos',
#     'Phonetic Spelling': "(al-ay-thee-nos')",
#     'Definition': 'TRUE',
#     'Usage': 'true (lit: made of truth), real, genuine.'},
#    'examples': [('φῶς τὸ ἀληθινὸν ὃ φωτίζει',
#      ' light true that which enlightens'),
#     ('ὅτε οἱ ἀληθινοὶ προσκυνηταὶ προσκυνήσουσιν',
#      ' when the true worshippers will worship'),
#     ('λόγος ἐστὶν ἀληθινὸς ὅτι ἄλλος', ' saying is true That one')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'οὐ',
#     'Part of Speech': 'Particle, Negative',
#     'Transliteration': 'ou, ouk, ouch',
#     'Phonetic Spelling': '(oo)',
#     'Definition': 'not, no',
#     'Usage': 'no, not.'},
#    'examples': [('αὐτῆς καὶ οὐκ ἤθελεν παρακληθῆναι',
#      ' of her and not would be comforted'),
#     ('παρακληθῆναι ὅτι οὐκ εἰσίν ', ' be comforted because no more are they'),
#     ('ἐστίν οὗ οὐκ εἰμὶ ἱκανὸς', ' is he of whom not I am fit')]}),
#  ('Wik', <words.Word at 0x7f52fa3d1908>),
#  ('Bible',
#   {'concordances': {'Original Word': 'πατήρ, πατρός, ὁ',
#     'Part of Speech': 'Noun, Masculine',
#     'Transliteration': 'patér',
#     'Phonetic Spelling': "(pat-ayr')",
#     'Definition': 'a father',
#     'Usage': 'father, (Heavenly) Father, ancestor, elder, senior.'},
#    'examples': [('ἐν ἑαυτοῖς Πατέρα ἔχομεν τὸν',
#      ' within yourselves [For] father we have'),
#     ('Ζεβεδαίου τοῦ πατρὸς αὐτῶν καταρτίζοντας',
#      ' Zebedee the father of them mending'),
#     ('καὶ τὸν πατέρα αὐτῶν ἠκολούθησαν',
#      ' and the father of them they followed')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'πᾶς, πᾶσα, πᾶν',
#     'Part of Speech': 'Adjective',
#     'Transliteration': 'pas',
#     'Phonetic Spelling': '(pas)',
#     'Definition': 'all, every',
#     'Usage': 'all, the whole, every kind of.'},
#    'examples': [("ἐταράχθη καὶ πᾶσα Ἰεροσόλυμα μετ'",
#      ' he was troubled and all Jerusalem with'),
#     ('καὶ συναγαγὼν πάντας τοὺς ἀρχιερεῖς',
#      ' And having gathered together all the chief priests'),
#     ('ἀποστείλας ἀνεῖλεν πάντας τοὺς παῖδας',
#      ' having sent forth he put to death all the boys')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'γεννάω',
#     'Part of Speech': 'Verb',
#     'Transliteration': 'gennaó',
#     'Phonetic Spelling': "(ghen-nah'-o)",
#     'Definition': 'to beget, to bring forth',
#     'Usage': 'I beget (of the male), (of the female) I bring forth, give birth to.'},
#    'examples': [('Ἰσαὰκ δὲ ἐγέννησεν τὸν Ἰακώβ',
#      ' Isaac moreover was father of Jacob'),
#     ('Ἰακὼβ δὲ ἐγέννησεν τὸν Ἰούδαν', ' Jacob moreover was father of Judah'),
#     ('Ἰούδας δὲ ἐγέννησεν τὸν Φαρὲς',
#      ' Judah moreover was father of Perez')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'ἡμέτερος, α, ον',
#     'Part of Speech': 'Possessive Pronoun',
#     'Transliteration': 'hémeteros',
#     'Phonetic Spelling': "(hay-met'-er-os)",
#     'Definition': 'our',
#     'Usage': 'our, our own.'},
#    'examples': [('κατά τόν ἡμέτερον νόμον ἠθελήσαμεν',
#      ' according to our law wished'),
#     ('αἵρεσιν τῆς ἡμετέρας θρησκείας ἔζησα',
#      ' sect of the of us religion I lived'),
#     ('εἰς τὴν ἡμετέραν διδασκαλίαν ἐγράφη',
#      ' for our instruction was written before')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'σωτηρία, ας, ἡ',
#     'Part of Speech': 'Noun, Feminine',
#     'Transliteration': 'sótéria',
#     'Phonetic Spelling': "(so-tay-ree'-ah)",
#     'Definition': 'deliverance, salvation',
#     'Usage': 'welfare, prosperity, deliverance, preservation, salvation, safety.'},
#    'examples': [('ἤγειρεν κέρας σωτηρίας ἡμῖν ἐν',
#      ' raised up a horn of salvation for us in'),
#     ('σωτηρίαν ἐξ ἐχθρῶν', ' salvation from enemies'),
#     ('δοῦναι γνῶσιν σωτηρίας τῷ λαῷ',
#      ' to give knowledge of salvation to people')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'κατέρχομαι',
#     'Part of Speech': 'Verb',
#     'Transliteration': 'katerchomai',
#     'Phonetic Spelling': "(kat-er'-khom-ahee)",
#     'Definition': 'to come down',
#     'Usage': 'I come down from sky to earth, or from high land to lower land (or to the coast), or from the high seas to the shore.'},
#    'examples': [('ἑξῆς ἡμέρᾳ κατελθόντων αὐτῶν ἀπὸ',
#      ' next day on having come down of them from'),
#     ('Φίλιππος δὲ κατελθὼν εἰς τὴν', ' Philip moreover having gone down to'),
#     ('διὰ πάντων κατελθεῖν καὶ πρὸς',
#      ' through all [quarters] went down also to')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'οὐρανός, οῦ, ὁ',
#     'Part of Speech': 'Noun, Masculine',
#     'Transliteration': 'ouranos',
#     'Phonetic Spelling': "(oo-ran-os')",
#     'Definition': 'heaven',
#     'Usage': 'heaven, (a) the visible heavens: the atmosphere, the sky, the starry heavens, (b) the spiritual heavens.'},
#    'examples': [('αὐτῷ οἱ οὐρανοί καὶ εἶδεν',
#      ' to him the heavens and he saw'),
#     ('ἐκ τῶν οὐρανῶν λέγουσα Οὗτός', ' out of the heavens saying This'),
#     ('βασιλεία τῶν οὐρανῶν ', ' kingdom of the heavens')]}),
#  ('Wik', <words.Word at 0x7f52f8e6eeb8>),
#  ('Bible',
#   {'concordances': {'Original Word': 'πνεῦμα, ατος, τό',
#     'Part of Speech': 'Noun, Neuter',
#     'Transliteration': 'pneuma',
#     'Phonetic Spelling': "(pnyoo'-mah)",
#     'Definition': 'wind, spirit',
#     'Usage': 'wind, breath, spirit.'},
#    'examples': [('γεννηθὲν ἐκ πνεύματός ἐστιν ἁγίου',
#      ' having been conceived from [the] Spirit is Holy'),
#     ('βαπτίσει ἐν πνεύματι ἁγίῳ καὶ',
#      ' will baptize with [the] Spirit Holy and'),
#     ('εἶδεν τὸ πνεῦμα τοῦ θεοῦ', ' he saw the Spirit of God')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'πνεῦμα, ατος, τό',
#     'Part of Speech': 'Noun, Neuter',
#     'Transliteration': 'pneuma',
#     'Phonetic Spelling': "(pnyoo'-mah)",
#     'Definition': 'wind, spirit',
#     'Usage': 'wind, breath, spirit.'},
#    'examples': [('γεννηθὲν ἐκ πνεύματός ἐστιν ἁγίου',
#      ' having been conceived from [the] Spirit is Holy'),
#     ('βαπτίσει ἐν πνεύματι ἁγίῳ καὶ',
#      ' will baptize with [the] Spirit Holy and'),
#     ('εἶδεν τὸ πνεῦμα τοῦ θεοῦ', ' he saw the Spirit of God')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'Μαρία, ας, ἡ',
#     'Part of Speech': 'Noun, Feminine; Proper Noun, Indeclinable',
#     'Transliteration': 'Maria or Mariam',
#     'Phonetic Spelling': "(mar-ee'-ah)",
#     'Definition': 'Mary, the name of several Christian women',
#     'Usage': 'Mary, Miriam, (a) the mother of Jesus, (b) of Magdala, (c) sister of Martha and Lazarus, (d) wife of Cleopas, (e) mother of John Mark, (f) a Christian woman in Rome.'},
#    'examples': [('μητρὸς αὐτοῦ Μαρίας τῷ Ἰωσήφ',
#      ' mother of him Mary to Joseph'),
#     ('φοβηθῇς παραλαβεῖν Μαρίαν τὴν γυναῖκά',
#      ' fear to take to [you] Mary [as] the wife'),
#     ('παιδίον μετὰ Μαρίας τῆς μητρὸς', ' child with Mary the mother')]}),
#  ('Bible',
#   {'concordances': {'Original Word': 'παρθένος, ου, ὁ, ἡ',
#     'Part of Speech': 'Noun, Feminine',
#     'Transliteration': 'parthenos',
#     'Phonetic Spelling': "(par-then'-os)",
#     'Definition': 'a maiden, a virgin',
#     'Usage': 'a maiden, virgin; extended to men who have not known women.'},
#    'examples': [('οὐρανῶν δέκα παρθένοις αἵτινες λαβοῦσαι',
#      ' heavens ten virgins who having taken'),
#     ('πᾶσαι αἱ παρθένοι ἐκεῖναι καὶ', ' all the virgins those and'),
#     ('αἱ λοιπαὶ παρθένοι λέγουσαι Κύριε', ' the other virgins saying Lord')]})]

# %%
blank = []
for item in data:
    if item[0] != "Bible":
       blank.append(item)

# %%
blank[1][2].name
# Out:
# 'σαρκόω'

# %%
blanks
# Out:
# ['ἐνανθρωπήσαντα',
#  'Σταυρωθέντα',
#  'ζωοποιόν',
#  'καθολικὴν',
#  'ἀποστολικὴν',
#  'Προσδοκῶ']

# %%
ὁμολογῶ
